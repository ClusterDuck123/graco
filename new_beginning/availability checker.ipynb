# %%
import os
import pandas as pd

DATA_DIRECTORY = "/media/clusterduck123/joe/data"
RAW_DATA_DIRECTORY = f"{DATA_DIRECTORY}/raw-data"
YEAST_DIRECTORY = f"{DATA_DIRECTORY}/processed-data/yeast"
HUMAN_DIRECTORY = f"{DATA_DIRECTORY}/processed-data/human"

# %%
def get_maxrun(DIRECTORY):
    splitted_file_names = [name.split('_') for name in os.listdir(DIRECTORY)]
    pre_runs = [int(run) for run, ncluster, db_txt in splitted_file_names]
    if pre_runs:
        return max(pre_runs)
    else:
        return 0

# %% [markdown]
# # Yeast

# %% [markdown]
# ## Clusters

# %%
CLUSTER_DIRECTORY = f"{YEAST_DIRECTORY}/clusterings"

for feature in os.listdir(CLUSTER_DIRECTORY):
    for distance in os.listdir(f"{CLUSTER_DIRECTORY}/{feature}"):
        maxrun = get_maxrun(f"{CLUSTER_DIRECTORY}/{feature}/{distance}/kmedoid")
        print(feature, distance, maxrun)
    print()
# Out:
# GCV-DG cosine 28
# GCV-DG euclidean 28
# GCV-DG seuclidean 28
# GCV-DG cityblock 28
# GCV-DG normalized2_l1 28
# GCV-DG normalized2_l2 28
# GCV-DG canberra 29
# GCV-DG mahalanobis 28
# GCV-DG correlation 28
# GCV-DG chebyshev 29
# GCV-DG normalized1_linf 28
# GCV-DG hellinger 29
# GCV-DG normalized1_l1 28
# GCV-DG normalized2_linf 28
# GCV-DG braycurtis 29
# GCV-DG sqeuclidean 28
# GCV-DG normalized1_l2 28
#
# GCV-G cosine 5
# GCV-G euclidean 5
# GCV-G seuclidean 5
# GCV-G cityblock 5
# GCV-G normalized2_l1 5
# GCV-G normalized2_l2 5
# GCV-G canberra 6
# GCV-G mahalanobis 5
# GCV-G correlation 5
# GCV-G chebyshev 6
# GCV-G normalized1_linf 5
# GCV-G normalized1_l1 5
# GCV-G normalized2_linf 5
# GCV-G braycurtis 6
# GCV-G sqeuclidean 5
# GCV-G normalized1_l2 5
#
# GCV-orca canberra 19
#
# GCV-all2 cosine 0
# GCV-all2 euclidean 0
# GCV-all2 cityblock 0
# GCV-all2 canberra 20
# GCV-all2 correlation 0
# GCV-all2 chebyshev 0
# GCV-all2 hellinger 0
# GCV-all2 braycurtis 0
#
# GCV-orca+ canberra 0
#
# GCV-A cosine 5
# GCV-A euclidean 5
# GCV-A seuclidean 5
# GCV-A cityblock 6
# GCV-A normalized2_l1 5
# GCV-A normalized2_l2 5
# GCV-A canberra 6
# GCV-A mahalanobis 5
# GCV-A correlation 6
# GCV-A chebyshev 6
# GCV-A normalized1_linf 5
# GCV-A normalized1_l1 5
# GCV-A normalized2_linf 5
# GCV-A braycurtis 6
# GCV-A sqeuclidean 6
# GCV-A normalized1_l2 5
#
# GCV-DA cosine 4
# GCV-DA euclidean 4
# GCV-DA seuclidean 4
# GCV-DA cityblock 4
# GCV-DA normalized2_l1 4
# GCV-DA normalized2_l2 4
# GCV-DA canberra 4
# GCV-DA mahalanobis 4
# GCV-DA correlation 4
# GCV-DA chebyshev 4
# GCV-DA normalized1_linf 4
# GCV-DA normalized1_l1 4
# GCV-DA normalized2_linf 4
# GCV-DA braycurtis 4
# GCV-DA sqeuclidean 4
# GCV-DA normalized1_l2 4
#
# GDV cosine 5
# GDV euclidean 5
# GDV seuclidean 5
# GDV cityblock 6
# GDV normalized2_l1 5
# GDV normalized2_l2 5
# GDV GDV_similarity 6
# GDV canberra 6
# GDV mahalanobis 5
# GDV correlation 6
# GDV chebyshev 6
# GDV normalized1_linf 5
# GDV hellinger 0
# GDV normalized1_l1 5
# GDV normalized2_linf 5
# GDV braycurtis 6
# GDV sqeuclidean 6
# GDV normalized1_l2 5
#
# GCV-all1 cosine 4
# GCV-all1 euclidean 4
# GCV-all1 seuclidean 3
# GCV-all1 cityblock 4
# GCV-all1 normalized2_l1 3
# GCV-all1 normalized2_l2 3
# GCV-all1 canberra 4
# GCV-all1 mahalanobis 4
# GCV-all1 correlation 4
# GCV-all1 chebyshev 4
# GCV-all1 normalized1_linf 4
# GCV-all1 hellinger 4
# GCV-all1 normalized1_l1 4
# GCV-all1 normalized2_linf 3
# GCV-all1 braycurtis 4
# GCV-all1 sqeuclidean 3
# GCV-all1 normalized1_l2 4

# %% [markdown]
# # p-values

# %%
CLUSTER_DIRECTORY = f"{YEAST_DIRECTORY}/p-values"

for feature in os.listdir(CLUSTER_DIRECTORY):
    for distance in os.listdir(  f"{CLUSTER_DIRECTORY}/{feature}"):
        for aspect in os.listdir(f"{CLUSTER_DIRECTORY}/{feature}/{distance}/kmedoid"):
            maxrun = get_maxrun( f"{CLUSTER_DIRECTORY}/{feature}/{distance}/kmedoid/{aspect}")
            print(feature.ljust(6), distance.ljust(16), aspect, maxrun)
        print()
    print()
# Out:
# GCV-DG cosine           BP 9
# GCV-DG cosine           MF 9
# GCV-DG cosine           CC 9
#
# GCV-DG euclidean        BP 9
# GCV-DG euclidean        MF 9
# GCV-DG euclidean        CC 9
#
# GCV-DG seuclidean       BP 9
# GCV-DG seuclidean       MF 9
# GCV-DG seuclidean       CC 9
#
# GCV-DG cityblock        BP 9
# GCV-DG cityblock        MF 28
# GCV-DG cityblock        CC 27
#
# GCV-DG normalized2_l1   BP 9
# GCV-DG normalized2_l1   MF 9
# GCV-DG normalized2_l1   CC 9
#
# GCV-DG normalized2_l2   BP 9
# GCV-DG normalized2_l2   MF 9
# GCV-DG normalized2_l2   CC 9
#
# GCV-DG canberra         BP 9
# GCV-DG canberra         MF 28
# GCV-DG canberra         CC 27
#
# GCV-DG mahalanobis      BP 9
# GCV-DG mahalanobis      MF 9
# GCV-DG mahalanobis      CC 9
#
# GCV-DG correlation      BP 9
# GCV-DG correlation      MF 9
# GCV-DG correlation      CC 9
#
# GCV-DG chebyshev        BP 9
# GCV-DG chebyshev        MF 28
# GCV-DG chebyshev        CC 27
#
# GCV-DG normalized1_linf BP 9
# GCV-DG normalized1_linf MF 9
# GCV-DG normalized1_linf CC 9
#
# GCV-DG hellinger        BP 9
# GCV-DG hellinger        MF 9
# GCV-DG hellinger        CC 9
#
# GCV-DG normalized1_l1   BP 9
# GCV-DG normalized1_l1   MF 9
# GCV-DG normalized1_l1   CC 9
#
# GCV-DG normalized2_linf BP 9
# GCV-DG normalized2_linf MF 9
# GCV-DG normalized2_linf CC 9
#
# GCV-DG braycurtis       BP 9
# GCV-DG braycurtis       MF 28
# GCV-DG braycurtis       CC 27
#
# GCV-DG sqeuclidean      BP 9
# GCV-DG sqeuclidean      MF 9
# GCV-DG sqeuclidean      CC 9
#
# GCV-DG normalized1_l2   BP 9
# GCV-DG normalized1_l2   MF 9
# GCV-DG normalized1_l2   CC 9
#
#
# GCV-G  cosine           CC 5
#
# GCV-G  euclidean        CC 5
#
# GCV-G  cityblock        CC 5
#
# GCV-G  canberra         CC 6
#
# GCV-G  correlation      CC 5
#
# GCV-G  chebyshev        CC 5
#
# GCV-G  hellinger        CC 0
#
# GCV-G  braycurtis       CC 6
#
#
# GCV-orca canberra         BP 9
# GCV-orca canberra         MF 9
# GCV-orca canberra         CC 9
#
#
# GCV-all2 canberra         BP 4
# GCV-all2 canberra         MF 4
# GCV-all2 canberra         CC 4
#
# GCV-all2 braycurtis       CC 0
#
#
# GCV-orca+ canberra         BP 6
# GCV-orca+ canberra         MF 5
# GCV-orca+ canberra         CC 9
#
#
# GCV-DA cosine           CC 4
#
# GCV-DA euclidean        CC 4
#
# GCV-DA cityblock        CC 4
#
# GCV-DA canberra         CC 4
#
# GCV-DA correlation      CC 4
#
# GCV-DA chebyshev        CC 4
#
# GCV-DA hellinger        CC 0
#
# GCV-DA braycurtis       CC 4
#
#
# GDV    GDV_similarity   BP 6
# GDV    GDV_similarity   MF 6
# GDV    GDV_similarity   CC 6
#
# GDV    mahalanobis      BP 5
# GDV    mahalanobis      MF 5
# GDV    mahalanobis      CC 5
#
#
# GCV-all1 canberra         BP 4
# GCV-all1 canberra         MF 4
# GCV-all1 canberra         CC 4

# %% [markdown]
# # Enrichment

# %%
ENRICHMENT_DIRECTORY = f"{YEAST_DIRECTORY}/enrichments"

for feature in os.listdir(ENRICHMENT_DIRECTORY):
    for distance in sorted(os.listdir(          f"{ENRICHMENT_DIRECTORY}/{feature}")):
        for aspect in os.listdir(        f"{ENRICHMENT_DIRECTORY}/{feature}/{distance}/kmedoid"):
            for correction in os.listdir(f"{ENRICHMENT_DIRECTORY}/{feature}/{distance}/kmedoid/{aspect}"):
                with open(               f"{ENRICHMENT_DIRECTORY}/{feature}/{distance}/kmedoid/{aspect}/"
                                         f"{correction}/clusters.csv", 'r') as f:
                    l1 = len(f.readline().strip(',\n').split(','))
                with open(               f"{ENRICHMENT_DIRECTORY}/{feature}/{distance}/kmedoid/{aspect}/"
                                         f"{correction}/GO-terms.csv", 'r') as f:
                    l2 = len(f.readline().strip(',\n').split(','))
                with open(               f"{ENRICHMENT_DIRECTORY}/{feature}/{distance}/kmedoid/{aspect}/"
                                         f"{correction}/genes.csv", 'r') as f:
                    l3 = len(f.readline().strip(',\n').split(','))

                print(feature.ljust(6), distance.ljust(16), aspect, correction, (l1+l2+l3)/3)
        print()
    print()
# Out:
# GCV-DG braycurtis       BP BH 10.0
# GCV-DG braycurtis       BP BY 10.0
# GCV-DG braycurtis       MF BH 29.0
# GCV-DG braycurtis       MF BY 29.0
# GCV-DG braycurtis       CC BH 28.0
# GCV-DG braycurtis       CC BY 28.0
#
# GCV-DG canberra         BP BH 10.0
# GCV-DG canberra         BP BY 10.0
# GCV-DG canberra         MF BH 29.0
# GCV-DG canberra         MF BY 29.0
# GCV-DG canberra         CC BH 28.0
# GCV-DG canberra         CC BY 28.0
#
# GCV-DG chebyshev        BP BH 10.0
# GCV-DG chebyshev        BP BY 10.0
# GCV-DG chebyshev        MF BH 29.0
# GCV-DG chebyshev        MF BY 29.0
# GCV-DG chebyshev        CC BH 28.0
# GCV-DG chebyshev        CC BY 28.0
#
# GCV-DG cityblock        BP BH 10.0
# GCV-DG cityblock        BP BY 10.0
# GCV-DG cityblock        MF BH 29.0
# GCV-DG cityblock        MF BY 29.0
# GCV-DG cityblock        CC BH 28.0
# GCV-DG cityblock        CC BY 28.0
#
# GCV-DG correlation      BP BH 10.0
# GCV-DG correlation      BP BY 10.0
# GCV-DG correlation      MF BH 10.0
# GCV-DG correlation      MF BY 10.0
# GCV-DG correlation      CC BH 10.0
# GCV-DG correlation      CC BY 10.0
#
# GCV-DG cosine           BP BH 10.0
# GCV-DG cosine           BP BY 10.0
# GCV-DG cosine           MF BH 10.0
# GCV-DG cosine           MF BY 10.0
# GCV-DG cosine           CC BH 10.0
# GCV-DG cosine           CC BY 10.0
#
# GCV-DG euclidean        BP BH 10.0
# GCV-DG euclidean        BP BY 10.0
# GCV-DG euclidean        MF BH 10.0
# GCV-DG euclidean        MF BY 10.0
# GCV-DG euclidean        CC BH 10.0
# GCV-DG euclidean        CC BY 10.0
#
# GCV-DG hellinger        BP BH 10.0
# GCV-DG hellinger        BP BY 10.0
# GCV-DG hellinger        MF BH 10.0
# GCV-DG hellinger        MF BY 10.0
# GCV-DG hellinger        CC BH 10.0
# GCV-DG hellinger        CC BY 10.0
#
# GCV-DG mahalanobis      BP BH 10.0
# GCV-DG mahalanobis      BP BY 10.0
# GCV-DG mahalanobis      MF BH 10.0
# GCV-DG mahalanobis      MF BY 10.0
# GCV-DG mahalanobis      CC BH 10.0
# GCV-DG mahalanobis      CC BY 10.0
#
# GCV-DG normalized1_l1   BP BH 10.0
# GCV-DG normalized1_l1   BP BY 10.0
# GCV-DG normalized1_l1   MF BH 10.0
# GCV-DG normalized1_l1   MF BY 10.0
# GCV-DG normalized1_l1   CC BH 10.0
# GCV-DG normalized1_l1   CC BY 10.0
#
# GCV-DG normalized1_l2   BP BH 10.0
# GCV-DG normalized1_l2   BP BY 10.0
# GCV-DG normalized1_l2   MF BH 10.0
# GCV-DG normalized1_l2   MF BY 10.0
# GCV-DG normalized1_l2   CC BH 10.0
# GCV-DG normalized1_l2   CC BY 10.0
#
# GCV-DG normalized1_linf BP BH 10.0
# GCV-DG normalized1_linf BP BY 10.0
# GCV-DG normalized1_linf MF BH 10.0
# GCV-DG normalized1_linf MF BY 10.0
# GCV-DG normalized1_linf CC BH 10.0
# GCV-DG normalized1_linf CC BY 10.0
#
# GCV-DG normalized2_l1   BP BH 10.0
# GCV-DG normalized2_l1   BP BY 10.0
# GCV-DG normalized2_l1   MF BH 10.0
# GCV-DG normalized2_l1   MF BY 10.0
# GCV-DG normalized2_l1   CC BH 10.0
# GCV-DG normalized2_l1   CC BY 10.0
#
# GCV-DG normalized2_l2   BP BH 10.0
# GCV-DG normalized2_l2   BP BY 10.0
# GCV-DG normalized2_l2   MF BH 10.0
# GCV-DG normalized2_l2   MF BY 10.0
# GCV-DG normalized2_l2   CC BH 10.0
# GCV-DG normalized2_l2   CC BY 10.0
#
# GCV-DG normalized2_linf BP BH 10.0
# GCV-DG normalized2_linf BP BY 10.0
# GCV-DG normalized2_linf MF BH 10.0
# GCV-DG normalized2_linf MF BY 10.0
# GCV-DG normalized2_linf CC BH 10.0
# GCV-DG normalized2_linf CC BY 10.0
#
# GCV-DG seuclidean       BP BH 10.0
# GCV-DG seuclidean       BP BY 10.0
# GCV-DG seuclidean       MF BH 10.0
# GCV-DG seuclidean       MF BY 10.0
# GCV-DG seuclidean       CC BH 10.0
# GCV-DG seuclidean       CC BY 10.0
#
# GCV-DG sqeuclidean      BP BH 10.0
# GCV-DG sqeuclidean      BP BY 10.0
# GCV-DG sqeuclidean      MF BH 10.0
# GCV-DG sqeuclidean      MF BY 10.0
# GCV-DG sqeuclidean      CC BH 10.0
# GCV-DG sqeuclidean      CC BY 10.0
#
#
# GCV-orca canberra         BP BY 5.0
# GCV-orca canberra         MF BY 10.0
# GCV-orca canberra         CC BY 10.0
#
#
# GCV-all2 canberra         BP BY 4.0
# GCV-all2 canberra         MF BY 5.0
# GCV-all2 canberra         CC BY 5.0
#
#
# GCV-orca+ canberra         BP BY 7.0
# GCV-orca+ canberra         MF BY 10.0
# GCV-orca+ canberra         CC BY 10.0
#
#
# GDV    GDV_similarity   BP BH 7.0
# GDV    GDV_similarity   BP BY 7.0
# GDV    GDV_similarity   MF BH 7.0
# GDV    GDV_similarity   MF BY 7.0
# GDV    GDV_similarity   CC BH 7.0
# GDV    GDV_similarity   CC BY 7.0
#
# GDV    canberra         BP BY 5.0
# GDV    canberra         MF BH 7.0
# GDV    canberra         MF BY 7.0
# GDV    canberra         CC BH 7.0
# GDV    canberra         CC BY 7.0
#
# GDV    mahalanobis      BP BH 6.0
# GDV    mahalanobis      BP BY 6.0
# GDV    mahalanobis      MF BH 6.0
# GDV    mahalanobis      MF BY 6.0
# GDV    mahalanobis      CC BH 6.0
# GDV    mahalanobis      CC BY 6.0
#
# GDV    normalized1_linf BP BY 5.0
# GDV    normalized1_linf MF BY 6.0
# GDV    normalized1_linf CC BY 6.0
#
#
# GCV-all1 canberra         BP BY 5.0
# GCV-all1 canberra         MF BY 5.0
# GCV-all1 canberra         CC BY 5.0

# %% [markdown]
# # Human

# %% [markdown]
# ## Clusters

# %%
CLUSTER_DIRECTORY = f"{HUMAN_DIRECTORY}/clusterings"

for feature in os.listdir(CLUSTER_DIRECTORY):
    for distance in os.listdir(f"{CLUSTER_DIRECTORY}/{feature}"):
        maxrun = get_maxrun(f"{CLUSTER_DIRECTORY}/{feature}/{distance}/kmedoid")
        print(feature, distance, maxrun)
    print()
# Out:
# GDV normalized1-l1 14
# GDV cosine 0
# GDV euclidean 0
# GDV normalized1-l2 15
# GDV mahalanobis 17
# GDV GDV-similarity 16
# GDV normalized1-linf 14
# GDV chebyshev 0

# %%
from gprofiler import GProfiler

import os
import numpy as np
import pandas as pd

# %%
path = '/media/clusterduck123/joe/new_MareNostrum/clusterings/GI_Constanzo2016/GDV/mahalanobis/kmedoid'

# %%
for file in os.listdir(path):
    with open(f"{path}/{file}", 'r') as f:
        clusters = tuple(map(str.split,f))
    break

# %%
s = set()
for cluster in clusters:
    res = gp.profile(organism='scerevisiae',
                     query=cluster,
                     sources=['GO:BP'],
                     all_results=True)
    s.update(set(res.native))

# %%
len(s)
# Out:
# 4965

# %%
set(res.native)
# Out:
# {'GO:0071692',
#  'GO:1901361',
#  'GO:0008645',
#  'GO:0007059',
#  'GO:0015868',
#  'GO:0010498',
#  'GO:0006997',
#  'GO:0009063',
#  'GO:0005975',
#  'GO:0030163',
#  'GO:0051029',
#  'GO:0000122',
#  'GO:0006520',
#  'GO:0070071',
#  'GO:0051172',
#  'GO:0000501',
#  'GO:0030835',
#  'GO:0009896',
#  'GO:1901135',
#  'GO:0009310',
#  'GO:0045935',
#  'GO:0009225',
#  'GO:0006986',
#  'GO:0006281',
#  'GO:0016043',
#  'GO:0006396',
#  'GO:1903317',
#  'GO:0043543',
#  'GO:1901990',
#  'GO:0006473',
#  'GO:0019358',
#  'GO:0006897',
#  'GO:0006139',
#  'GO:0000460',
#  'GO:1903047',
#  'GO:0012501',
#  'GO:0062197',
#  'GO:0006820',
#  'GO:0097237',
#  'GO:0000947',
#  'GO:0010966',
#  'GO:0046184',
#  'GO:0042180',
#  'GO:0051127',
#  'GO:0097659',
#  'GO:0034613',
#  'GO:0006536',
#  'GO:0051716',
#  'GO:2000601',
#  'GO:0006486',
#  'GO:0007117',
#  'GO:0051236',
#  'GO:0030834',
#  'GO:0030866',
#  'GO:0071243',
#  'GO:0000154',
#  'GO:0006364',
#  'GO:0044271',
# ...

# %%
s = set()
s.update

# %%
? s.update

# %%
len(clusters[2])
# Out:
# 185

# %%
? gp.profile

# %%
df.native
# Out:
# 0       GO:0009228
# 1       GO:0042724
# 2       GO:0006772
# 3       GO:0042723
# 4       GO:0008972
#            ...
# 1848    GO:0019220
# 1849    GO:0019219
# 1850    GO:0018344
# 1851    GO:0018212
# 1852    GO:0051174
# Name: native, Length: 1853, dtype: object

# %%
df.source.unique()
# Out:
# array(['GO:BP', 'GO:MF', 'KEGG', 'WP', 'GO:CC', 'TF', 'HP'], dtype=object)

# %%
df[df.source=='GO:CC']
# Out:
#   source      native           name   p_value  significant  \
# 0  GO:CC  GO:0005622  intracellular  0.000473         True
#
#                                          description  term_size  query_size  \
# 0  "The living contents of a cell; the matter con...       4579          86
#
#    intersection_size  effective_domain_size  precision    recall    query  \
# 0                 85                   5501   0.988372  0.018563  query_1
#
#         parents
# 0  [GO:0005575]

# %%
len(query)
# Out:
# 93

# %%
import gprofiler

# %%
gprofiler.__version__
# Out:
# '1.0.0'

# %%
gp.profile(organism='hsapiens',
            query=['NR1H4','TRIP12','UBC','FCRL3','PLXNA3','GDNF','VPS11'])
# Out:
#   source      native                                         name   p_value  \
# 0  GO:BP  GO:0048585  negative regulation of response to stimulus  0.006047
# 1  GO:BP  GO:0002224         toll-like receptor signaling pathway  0.024278
# 2  GO:BP  GO:0048486   parasympathetic nervous system development  0.025966
# 3  GO:BP  GO:0034162       toll-like receptor 9 signaling pathway  0.049286
# 4  CORUM  CORUM:5669                        PlexinA3-Nrp1 complex  0.049643
# 5  CORUM  CORUM:5759                        PLXNA3-RANBPM complex  0.049643
#
#    significant                                        description  term_size  \
# 0         True  "Any process that stops, prevents, or reduces ...       1731
# 1         True  "Any series of molecular signals generated as ...        153
# 2         True  "The process whose specific outcome is the pro...         19
# 3         True  "Any series of molecular signals generated as ...         26
# ...

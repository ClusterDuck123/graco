# %%
from pyclustering.cluster.kmedoids import kmedoids
from functools import partial
from random import sample

import os
import time
import numpy as np
import pandas as pd
import networkx as nx

# %%
DATA_DIRECTORY = "/home/clusterduck123/Desktop/git/supplements/data"
YEAST_DIRECTORY = f"{DATA_DIRECTORY}/processed-data/organisms/yeast"
NETWORK_DIRECTORY = f"{YEAST_DIRECTORY}/networks"
MATRIX_DIRECTORY  = f"{YEAST_DIRECTORY}/distance-matrices"
ANNOTATION_DIRECTORY = f"{YEAST_DIRECTORY}/annotations"

# %% [markdown]
# # Clustering

# %%
def get_number_of_pre_runs(CLUSTER_DIRECTORY, distance, n_clusters = 99):
    splitted_file_names = [name.split('_') for name in os.listdir(CLUSTER_DIRECTORY)]
    pre_runs = [int(run) for run, ncluster, db_txt in splitted_file_names if ncluster == str(n_clusters)]
    if pre_runs:
        return max(pre_runs)
    else:
        return -1

# %% [markdown]
# ## GDV

# %%
MIN_CLUSTERS = 2
MAX_CLUSTERS = 100

all_distances = [filename.split('_')[0] for filename in os.listdir(f"{MATRIX_DIRECTORY}/GDV")]

# %%
method = 'kmedoid'

for run in range(49):
    for distance in all_distances:
        print(distance)
        
        CLUSTER_DIRECTORY = f"{YEAST_DIRECTORY}/clusterings/GDV/{distance}/{method}"
        if not os.path.exists(CLUSTER_DIRECTORY):
            os.makedirs(CLUSTER_DIRECTORY)
            
        df = pd.read_csv(f"{MATRIX_DIRECTORY}/GDV/{distance}_BioGRID.txt", delimiter=' ')
        D  = df.values.astype(float) 

        t1 = time.time()
        for n_clusters in range(MIN_CLUSTERS, MAX_CLUSTERS+1):
            initial_medoids = sample(range(len(D)), n_clusters)
            kmedoids_instance = kmedoids(D, initial_medoids, data_type='distance_matrix')
            kmedoids_instance.process()
            
            nr = get_number_of_pre_runs(CLUSTER_DIRECTORY, distance, MAX_CLUSTERS)

            with open(f"{CLUSTER_DIRECTORY}/{nr+1}_{n_clusters}_BioGRID.txt", 'w') as f:
                for cluster in kmedoids_instance.get_clusters():
                    f.write(' '.join(df.columns[cluster]) + '\n')
            t2 = time.time()
            print(f'{n_clusters}: {t2-t1:.2f}sec', end='\r')
        print()
# Out:
# mahalanobis
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-4ed50ce35ed8> in <module>
#       9             os.makedirs(CLUSTER_DIRECTORY)
#      10
# ---> 11         df = pd.read_csv(f"{MATRIX_DIRECTORY}/GDV/{distance}_BioGRID.txt", delimiter=' ')
#      12         D  = df.values.astype(float)
#      13
#
# ~/Desktop/git/supplements/venv/graco/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~/Desktop/git/supplements/venv/graco/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     461
#     462     try:
# --> 463         data = parser.read(nrows)
#     464     finally:
#     465         parser.close()
#
# ~/Desktop/git/supplements/venv/graco/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1152     def read(self, nrows=None):
#    1153         nrows = _validate_integer("nrows", nrows)
# -> 1154         ret = self._engine.read(nrows)
#    1155
#    1156         # May alter columns / col_dict
#
# ~/Desktop/git/supplements/venv/graco/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2057     def read(self, nrows=None):
#    2058         try:
# -> 2059             data = self._reader.read(nrows)
#    2060         except StopIteration:
#    2061             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# ~/Desktop/git/supplements/venv/graco/lib/python3.6/site-packages/pandas/core/dtypes/common.py in is_categorical_dtype(arr_or_dtype)
#     676
#     677
# --> 678 def is_categorical_dtype(arr_or_dtype):
#     679     """
#     680     Check whether an array-like or dtype is of the Categorical dtype.
#
# KeyboardInterrupt:

# %% [markdown]
# ## GCV-A

# %%
MIN_CLUSTERS = 2
MAX_CLUSTERS = 100

all_distances = [filename.split('_')[0] for filename in os.listdir(f"{MATRIX_DIRECTORY}/GCV-A")]

# %%
method = 'kmedoid'

for run in range(10):
    for distance in ['all1_normalized1-linf',
                     'all1_normalized1-l2', 'all2_normalized1-l2',
                     'all1_normalized1-l1', 'all2_normalized1-l1']:
        print(distance)
        
        CLUSTER_DIRECTORY = f"{YEAST_DIRECTORY}/clusterings/GCV-A/{distance}/{method}"
        if not os.path.exists(CLUSTER_DIRECTORY):
            os.makedirs(CLUSTER_DIRECTORY)
            
        df = pd.read_csv(f"{MATRIX_DIRECTORY}/GCV-A/{distance}_BioGRID.txt", delimiter=' ')
        D  = df.values.astype(float) 

        t1 = time.time()
        for n_clusters in range(MIN_CLUSTERS, MAX_CLUSTERS+1):
            initial_medoids = sample(range(len(D)), n_clusters)
            kmedoids_instance = kmedoids(D, initial_medoids, data_type='distance_matrix')
            kmedoids_instance.process()
            
            nr = get_number_of_pre_runs(CLUSTER_DIRECTORY, distance, MAX_CLUSTERS)

            with open(f"{CLUSTER_DIRECTORY}/{nr+1}_{n_clusters}_BioGRID.txt", 'w') as f:
                for cluster in kmedoids_instance.get_clusters():
                    f.write(' '.join(df.columns[cluster]) + '\n')
            t2 = time.time()
            print(f'{n_clusters}: {t2-t1:.2f}sec', end='\r')
        print()
# Out:
# all1_normalized1-linf
# 100: 658.71sec
# all1_normalized1-l2
# 100: 592.68sec
# all2_normalized1-l2
# 100: 608.73sec
# all1_normalized1-l1
# 100: 611.58sec
# all2_normalized1-l1
# 100: 574.11sec
# all1_normalized1-linf
# 100: 568.12sec
# all1_normalized1-l2
# 100: 570.96sec
# all2_normalized1-l2
# 100: 563.42sec
# all1_normalized1-l1
# 100: 591.96sec
# all2_normalized1-l1
# 100: 573.84sec
# all1_normalized1-linf
# 100: 550.58sec
# all1_normalized1-l2
# 100: 602.98sec
# all2_normalized1-l2
# 100: 605.44sec
# all1_normalized1-l1
# 100: 601.88sec
# all2_normalized1-l1
# 100: 586.09sec
# all1_normalized1-linf
# 100: 594.33sec
# all1_normalized1-l2
# 69: 404.05sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-8d55c1fc4057> in <module>
#      18             initial_medoids = sample(range(len(D)), n_clusters)
#      19             kmedoids_instance = kmedoids(D, initial_medoids, data_type='distance_matrix')
# ---> 20             kmedoids_instance.process()
#      21
#      22             nr = get_number_of_pre_runs(CLUSTER_DIRECTORY, distance, MAX_CLUSTERS)
#
# ~/Desktop/git/supplements/venv/graco/lib/python3.6/site-packages/pyclustering/cluster/kmedoids.py in process(self)
#     156         if self.__ccore is True:
#     157             ccore_metric = metric_wrapper.create_instance(self.__metric)
# --> 158             self.__clusters, self.__medoid_indexes = wrapper.kmedoids(self.__pointer_data, self.__medoid_indexes, self.__tolerance, self.__itermax, ccore_metric.get_pointer(), self.__data_type)
#     159
#     160         else:
#
# ~/Desktop/git/supplements/venv/graco/lib/python3.6/site-packages/pyclustering/core/kmedoids_wrapper.py in kmedoids(sample, medoids, tolerance, itermax, metric_pointer, data_type)
#      33
#      34 def kmedoids(sample, medoids, tolerance, itermax, metric_pointer, data_type):
# ---> 35     pointer_data = package_builder(sample, c_double).create()
#      36     medoids_package = package_builder(medoids, c_size_t).create()
#      37     c_data_type = convert_data_type(data_type)
#
# ~/Desktop/git/supplements/venv/graco/lib/python3.6/site-packages/pyclustering/core/pyclustering_package.py in create(self)
#     132
#     133         """
# --> 134         return self.__create_package(self.__dataset)
#     135
#     136
#
# ~/Desktop/git/supplements/venv/graco/lib/python3.6/site-packages/pyclustering/core/pyclustering_package.py in __create_package(self, dataset)
#     161
#     162         c_data_type = self.__fill_type(dataset_package, dataset)
# --> 163         self.__fill_data(dataset_package, c_data_type, dataset)
#     164
#     165         return pointer(dataset_package)
#
# ~/Desktop/git/supplements/venv/graco/lib/python3.6/site-packages/pyclustering/core/pyclustering_package.py in __fill_data(self, dataset_package, c_data_type, dataset)
#     202             package_data = (POINTER(pyclustering_package) * len(dataset))()
#     203             for index in range(len(dataset)):
# --> 204                 package_data[index] = self.__create_package(dataset[index])
#     205
#     206             dataset_package.data = cast(package_data, POINTER(c_void_p))
#
# ~/Desktop/git/supplements/venv/graco/lib/python3.6/site-packages/pyclustering/core/pyclustering_package.py in __create_package(self, dataset)
#     161
#     162         c_data_type = self.__fill_type(dataset_package, dataset)
# --> 163         self.__fill_data(dataset_package, c_data_type, dataset)
#     164
#     165         return pointer(dataset_package)
#
# ~/Desktop/git/supplements/venv/graco/lib/python3.6/site-packages/pyclustering/core/pyclustering_package.py in __fill_data(self, dataset_package, c_data_type, dataset)
#     206             dataset_package.data = cast(package_data, POINTER(c_void_p))
#     207         else:
# --> 208             array_object = (c_data_type * len(dataset))(*dataset)
#     209             dataset_package.data = cast(array_object, POINTER(c_void_p))
#     210
#
# KeyboardInterrupt:

# %% [markdown]
# ## GCV-G

# %%
MIN_CLUSTERS = 2
MAX_CLUSTERS = 100

all_distances = [filename.split('_')[0] for filename in os.listdir(f"{MATRIX_DIRECTORY}/GCV-G")]

# %%
method = 'kmedoid'

for run in range(10):
    for distance in ['all1_normalized1-linf',
                     'all1_normalized1-l2', 'all2_normalized1-l2',
                     'all1_normalized1-l1', 'all2_normalized1-l1']:
        print(distance)
        
        CLUSTER_DIRECTORY = f"{YEAST_DIRECTORY}/clusterings/GCV-G/{distance}/{method}"
        if not os.path.exists(CLUSTER_DIRECTORY):
            os.makedirs(CLUSTER_DIRECTORY)
            
        df = pd.read_csv(f"{MATRIX_DIRECTORY}/GCV-G/{distance}_BioGRID.txt", delimiter=' ')
        D  = df.values.astype(float) 

        t1 = time.time()
        for n_clusters in range(MIN_CLUSTERS, MAX_CLUSTERS+1):
            initial_medoids = sample(range(len(D)), n_clusters)
            kmedoids_instance = kmedoids(D, initial_medoids, data_type='distance_matrix')
            kmedoids_instance.process()
            
            nr = get_number_of_pre_runs(CLUSTER_DIRECTORY, distance, MAX_CLUSTERS)

            with open(f"{CLUSTER_DIRECTORY}/{nr+1}_{n_clusters}_BioGRID.txt", 'w') as f:
                for cluster in kmedoids_instance.get_clusters():
                    f.write(' '.join(df.columns[cluster]) + '\n')
            t2 = time.time()
            print(f'{n_clusters}: {t2-t1:.2f}sec', end='\r')
        print()
# Out:
# all1_normalized1-linf
# 39: 226.22sec

# %% [markdown]
# # GCV-AD

# %%
MIN_CLUSTERS = 2
MAX_CLUSTERS = 100

all_distances = [filename.split('_')[0] for filename in os.listdir(f"{MATRIX_DIRECTORY}/GCV-AD")]

# %%
method = 'kmedoid'

for run in range(50):
    for distance in ['all1_normalized1-linf',
                     'all1_normalized1-l2', 'all2_normalized1-l2',
                     'all1_normalized1-l1', 'all2_normalized1-l1']:
        print(distance)
        
        CLUSTER_DIRECTORY = f"{YEAST_DIRECTORY}/clusterings/GCV-AD/{distance}/{method}"
        if not os.path.exists(CLUSTER_DIRECTORY):
            os.makedirs(CLUSTER_DIRECTORY)
            
        df = pd.read_csv(f"{MATRIX_DIRECTORY}/GCV-AD/{distance}_BioGRID.txt", delimiter=' ')
        D  = df.values.astype(float) 

        t1 = time.time()
        for n_clusters in range(MIN_CLUSTERS, MAX_CLUSTERS+1):
            initial_medoids = sample(range(len(D)), n_clusters)
            kmedoids_instance = kmedoids(D, initial_medoids, data_type='distance_matrix')
            kmedoids_instance.process()
            
            nr = get_number_of_pre_runs(CLUSTER_DIRECTORY, distance, MAX_CLUSTERS)

            with open(f"{CLUSTER_DIRECTORY}/{nr+1}_{n_clusters}_BioGRID.txt", 'w') as f:
                for cluster in kmedoids_instance.get_clusters():
                    f.write(' '.join(df.columns[cluster]) + '\n')
            t2 = time.time()
            print(f'{n_clusters}: {t2-t1:.2f}sec', end='\r')
        print()
# Out:
# all1_normalized1-linf
# 100: 599.54sec
# all1_normalized1-l2
# 100: 593.72sec
# all2_normalized1-l2
# 100: 615.18sec
# all1_normalized1-l1
# 100: 606.26sec
# all2_normalized1-l1
# 100: 595.18sec
# all1_normalized1-linf
# 100: 604.13sec
# all1_normalized1-l2
# 100: 591.32sec
# all2_normalized1-l2
# 100: 595.40sec
# all1_normalized1-l1
# 100: 600.05sec
# all2_normalized1-l1
# 100: 601.64sec
# all1_normalized1-linf
# 100: 593.36sec
# all1_normalized1-l2
# 100: 631.78sec
# all2_normalized1-l2
# 100: 617.85sec
# all1_normalized1-l1
# 100: 597.47sec
# all2_normalized1-l1
# 100: 614.92sec
# all1_normalized1-linf
# 100: 602.92sec
# all1_normalized1-l2
# 100: 592.98sec
# all2_normalized1-l2
# 100: 580.80sec
# all1_normalized1-l1
# 100: 564.18sec
# all2_normalized1-l1
# 100: 566.26sec
# all1_normalized1-linf
# 100: 571.64sec
# all1_normalized1-l2
# 100: 591.27sec
# all2_normalized1-l2
# 100: 757.71sec
# all1_normalized1-l1
# 100: 697.25sec
# all2_normalized1-l1
# 100: 609.66sec
# all1_normalized1-linf
# 100: 598.44sec
# all1_normalized1-l2
# 100: 606.34sec
# all2_normalized1-l2
# 100: 604.41sec
# all1_normalized1-l1
# 100: 594.37sec
# all2_normalized1-l1
# 100: 605.02sec
# all1_normalized1-linf
# 100: 599.78sec
# all1_normalized1-l2
# 100: 595.90sec
# all2_normalized1-l2
# 100: 649.62sec
# all1_normalized1-l1
# 100: 641.74sec
# all2_normalized1-l1
# 100: 606.63sec
# all1_normalized1-linf
# 100: 632.71sec
# all1_normalized1-l2
# 100: 623.76sec
# all2_normalized1-l2
# 100: 600.11sec
# all1_normalized1-l1
# 100: 614.14sec
# all2_normalized1-l1
# 18: 106.16sec
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-5-0853e7949cda> in <module>
#      24             with open(f"{CLUSTER_DIRECTORY}/{nr+1}_{n_clusters}_BioGRID.txt", 'w') as f:
#      25                 for cluster in kmedoids_instance.get_clusters():
# ---> 26                     f.write(' '.join(df.columns[cluster]) + '\n')
#      27             t2 = time.time()
#      28             print(f'{n_clusters}: {t2-t1:.2f}sec', end='\r')
#
# OSError: [Errno 28] No space left on device

# %% [markdown]
# # GCV-DG

# %%
MIN_CLUSTERS = 2
MAX_CLUSTERS = 100

all_distances = [filename.split('_')[0] for filename in os.listdir(f"{MATRIX_DIRECTORY}/GCV-DG")]

# %%
method = 'kmedoid'

for run in range(50):
    for distance in ['all1_normalized1-linf',
                     'all1_normalized1-l2', 'all2_normalized1-l2',
                     'all1_normalized1-l1', 'all2_normalized1-l1']:
        print(distance)
        
        CLUSTER_DIRECTORY = f"{YEAST_DIRECTORY}/clusterings/GCV-DG/{distance}/{method}"
        if not os.path.exists(CLUSTER_DIRECTORY):
            os.makedirs(CLUSTER_DIRECTORY)
            
        df = pd.read_csv(f"{MATRIX_DIRECTORY}/GCV-DG/{distance}_BioGRID.txt", delimiter=' ')
        D  = df.values.astype(float) 

        t1 = time.time()
        for n_clusters in range(MIN_CLUSTERS, MAX_CLUSTERS+1):
            initial_medoids = sample(range(len(D)), n_clusters)
            kmedoids_instance = kmedoids(D, initial_medoids, data_type='distance_matrix')
            kmedoids_instance.process()
            
            nr = get_number_of_pre_runs(CLUSTER_DIRECTORY, distance, MAX_CLUSTERS)

            with open(f"{CLUSTER_DIRECTORY}/{nr+1}_{n_clusters}_BioGRID.txt", 'w') as f:
                for cluster in kmedoids_instance.get_clusters():
                    f.write(' '.join(df.columns[cluster]) + '\n')
            t2 = time.time()
            print(f'{n_clusters}: {t2-t1:.2f}sec', end='\r')
        print()
# Out:
# all1_normalized1-linf
# 100: 607.15sec
# all1_normalized1-l2
# 100: 576.63sec
# all2_normalized1-l2
# 100: 574.45sec
# all1_normalized1-l1
# 100: 557.20sec
# all2_normalized1-l1
# 100: 569.55sec
# all1_normalized1-linf
# 100: 574.96sec
# all1_normalized1-l2
# 100: 580.12sec
# all2_normalized1-l2
# 100: 565.28sec
# all1_normalized1-l1
# 100: 582.14sec
# all2_normalized1-l1
# 100: 574.68sec
# all1_normalized1-linf
# 100: 557.73sec
# all1_normalized1-l2
# 100: 599.30sec
# all2_normalized1-l2
# 100: 571.78sec
# all1_normalized1-l1
# 100: 559.61sec
# all2_normalized1-l1
# 100: 580.66sec
# all1_normalized1-linf
# 100: 574.55sec
# all1_normalized1-l2
# 100: 581.95sec
# all2_normalized1-l2
# 100: 568.93sec
# all1_normalized1-l1
# 100: 563.75sec
# all2_normalized1-l1
# 100: 570.03sec
# all1_normalized1-linf
# 100: 569.61sec
# all1_normalized1-l2
# 100: 567.17sec
# all2_normalized1-l2
# 100: 570.55sec
# all1_normalized1-l1
# 100: 569.99sec
# all2_normalized1-l1
# 100: 575.81sec
# all1_normalized1-linf
# 100: 571.72sec
# all1_normalized1-l2
# 100: 576.52sec
# all2_normalized1-l2
# 100: 576.46sec
# all1_normalized1-l1
# 100: 566.08sec
# all2_normalized1-l1
# 100: 571.39sec
# all1_normalized1-linf
# 100: 571.85sec
# all1_normalized1-l2
# 100: 558.86sec
# all2_normalized1-l2
# 100: 558.71sec
# all1_normalized1-l1
# 100: 568.63sec
# all2_normalized1-l1
# 100: 563.60sec
# all1_normalized1-linf
# 100: 575.33sec
# all1_normalized1-l2
# 100: 565.07sec
# all2_normalized1-l2
# 100: 563.91sec
# all1_normalized1-l1
# 100: 566.44sec
# all2_normalized1-l1
# 100: 571.26sec
# all1_normalized1-linf
# 100: 563.59sec
# all1_normalized1-l2
# 100: 579.41sec
# all2_normalized1-l2
# 100: 570.32sec
# all1_normalized1-l1
# 100: 566.10sec
# all2_normalized1-l1
# 100: 566.33sec
# all1_normalized1-linf
# 100: 569.45sec
# all1_normalized1-l2
# 100: 560.40sec
# all2_normalized1-l2
# 100: 577.85sec
# all1_normalized1-l1
# 100: 573.17sec
# all2_normalized1-l1
# 100: 562.53sec
# all1_normalized1-linf
# 100: 578.65sec
# all1_normalized1-l2
# 100: 572.86sec
# all2_normalized1-l2
# 100: 565.21sec
# all1_normalized1-l1
# 100: 585.28sec
# all2_normalized1-l1
# 100: 571.80sec
# all1_normalized1-linf
# 100: 568.86sec
# all1_normalized1-l2
# 100: 572.33sec
# all2_normalized1-l2
# 100: 573.89sec
# all1_normalized1-l1
# 100: 561.21sec
# all2_normalized1-l1
# 100: 576.55sec
# all1_normalized1-linf
# 100: 561.98sec
# all1_normalized1-l2
# 100: 558.19sec
# all2_normalized1-l2
# 100: 582.06sec
# all1_normalized1-l1
# 100: 577.01sec
# all2_normalized1-l1
# 100: 558.91sec
# all1_normalized1-linf
# 100: 560.09sec
# all1_normalized1-l2
# 100: 569.66sec
# all2_normalized1-l2
# 100: 568.07sec
# all1_normalized1-l1
# 100: 577.76sec
# all2_normalized1-l1
# 100: 569.60sec
# all1_normalized1-linf
# 100: 564.04sec
# all1_normalized1-l2
# 100: 573.93sec
# all2_normalized1-l2
# 100: 576.54sec
# all1_normalized1-l1
# 100: 566.28sec
# all2_normalized1-l1
# 100: 571.86sec
# all1_normalized1-linf
# 100: 570.76sec
# all1_normalized1-l2
# 100: 566.16sec
# all2_normalized1-l2
# 100: 578.58sec
# all1_normalized1-l1
# 14: 77.87sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-5a9fb0370935> in <module>
#      18             initial_medoids = sample(range(len(D)), n_clusters)
#      19             kmedoids_instance = kmedoids(D, initial_medoids, data_type='distance_matrix')
# ---> 20             kmedoids_instance.process()
#      21
#      22             nr = get_number_of_pre_runs(CLUSTER_DIRECTORY, distance, MAX_CLUSTERS)
#
# ~/Desktop/git/supplements/venv/graco/lib/python3.6/site-packages/pyclustering/cluster/kmedoids.py in process(self)
#     156         if self.__ccore is True:
#     157             ccore_metric = metric_wrapper.create_instance(self.__metric)
# --> 158             self.__clusters, self.__medoid_indexes = wrapper.kmedoids(self.__pointer_data, self.__medoid_indexes, self.__tolerance, self.__itermax, ccore_metric.get_pointer(), self.__data_type)
#     159
#     160         else:
#
# ~/Desktop/git/supplements/venv/graco/lib/python3.6/site-packages/pyclustering/core/kmedoids_wrapper.py in kmedoids(sample, medoids, tolerance, itermax, metric_pointer, data_type)
#      33
#      34 def kmedoids(sample, medoids, tolerance, itermax, metric_pointer, data_type):
# ---> 35     pointer_data = package_builder(sample, c_double).create()
#      36     medoids_package = package_builder(medoids, c_size_t).create()
#      37     c_data_type = convert_data_type(data_type)
#
# ~/Desktop/git/supplements/venv/graco/lib/python3.6/site-packages/pyclustering/core/pyclustering_package.py in create(self)
#     132
#     133         """
# --> 134         return self.__create_package(self.__dataset)
#     135
#     136
#
# ~/Desktop/git/supplements/venv/graco/lib/python3.6/site-packages/pyclustering/core/pyclustering_package.py in __create_package(self, dataset)
#     161
#     162         c_data_type = self.__fill_type(dataset_package, dataset)
# --> 163         self.__fill_data(dataset_package, c_data_type, dataset)
#     164
#     165         return pointer(dataset_package)
#
# ~/Desktop/git/supplements/venv/graco/lib/python3.6/site-packages/pyclustering/core/pyclustering_package.py in __fill_data(self, dataset_package, c_data_type, dataset)
#     202             package_data = (POINTER(pyclustering_package) * len(dataset))()
#     203             for index in range(len(dataset)):
# --> 204                 package_data[index] = self.__create_package(dataset[index])
#     205
#     206             dataset_package.data = cast(package_data, POINTER(c_void_p))
#
# ~/Desktop/git/supplements/venv/graco/lib/python3.6/site-packages/pyclustering/core/pyclustering_package.py in __create_package(self, dataset)
#     161
#     162         c_data_type = self.__fill_type(dataset_package, dataset)
# --> 163         self.__fill_data(dataset_package, c_data_type, dataset)
#     164
#     165         return pointer(dataset_package)
#
# ~/Desktop/git/supplements/venv/graco/lib/python3.6/site-packages/pyclustering/core/pyclustering_package.py in __fill_data(self, dataset_package, c_data_type, dataset)
#     206             dataset_package.data = cast(package_data, POINTER(c_void_p))
#     207         else:
# --> 208             array_object = (c_data_type * len(dataset))(*dataset)
#     209             dataset_package.data = cast(array_object, POINTER(c_void_p))
#     210
#
# KeyboardInterrupt:

# %% [markdown]
# ### gGCV

# %%
MIN_CLUSTERS = 2
MAX_CLUSTERS = 100

all_distances = ['normalizedlinf']

# %%
# Automated
for run in range(49):
    for distance in all_distances:
        print(distance)

        if not os.path.exists(f"{CLUSTERS_DIRECTORY}/gGCV/{distance}"):
            os.makedirs(f"{CLUSTERS_DIRECTORY}/gGCV/{distance}")

        MATRIX_NAME = f"sc_BioGRID_gGCV_{distance}"
        with open(f"{MATRIX_DIRECTORY}/{MATRIX_NAME}.txt", 'r') as f:
            line = f.readline()
        D = np.loadtxt(f"{MATRIX_DIRECTORY}/{MATRIX_NAME}.txt", skiprows=1)

        int2gene = dict(enumerate(line.split()))
        
        t1 = time.time()
        for n_clusters in range(2, 100):
            nr = get_number_of_max_runs('gGCV', distance, MAX_CLUSTERS-1) # CAREFULL !!!!!
            initial_medoids = sample(range(len(D)), n_clusters)
            kmedoids_instance = kmedoids(D, initial_medoids, data_type='distance_matrix')
            kmedoids_instance.process()

            with open(f"{CLUSTERS_DIRECTORY}/gGCV/{distance}/{nr+1}_sc_BioGRID_{n_clusters}.txt", 'w') as f:
                for cluster in kmedoids_instance.get_clusters():
                    f.write(' '.join(map(int2gene.get,cluster)) + '\n')
            t2 = time.time()
            print(f'{n_clusters}: {t2-t1:.2f}sec', end='\r')
        print()
# Out:
# normalizedlinf
# 99: 569.67sec
# normalizedlinf
# 99: 555.84sec
# normalizedlinf
# 99: 554.14sec
# normalizedlinf
# 99: 555.52sec
# normalizedlinf
# 99: 554.21sec
# normalizedlinf
# 99: 555.25sec
# normalizedlinf
# 99: 554.59sec
# normalizedlinf
# 99: 554.19sec
# normalizedlinf
# 99: 554.66sec
# normalizedlinf
# 99: 555.05sec
# normalizedlinf
# 99: 554.81sec
# normalizedlinf
# 99: 554.58sec
# normalizedlinf
# 99: 554.33sec
# normalizedlinf
# 99: 554.85sec
# normalizedlinf
# 99: 555.31sec
# normalizedlinf
# 99: 554.66sec
# normalizedlinf
# 99: 554.98sec
# normalizedlinf
# 99: 554.77sec
# normalizedlinf
# 99: 555.27sec
# normalizedlinf
# 99: 555.33sec
# normalizedlinf
# 99: 554.48sec
# normalizedlinf
# 99: 555.08sec
# normalizedlinf
# 99: 555.41sec
# normalizedlinf
# 99: 554.54sec
# normalizedlinf
# 99: 554.56sec
# normalizedlinf
# 99: 556.31sec
# normalizedlinf
# 99: 554.94sec
# normalizedlinf
# 99: 555.55sec
# normalizedlinf
# 99: 554.78sec
# normalizedlinf
# 99: 555.50sec
# normalizedlinf
# 99: 555.09sec
# normalizedlinf
# 99: 554.69sec
# normalizedlinf
# 99: 554.88sec
# normalizedlinf
# 99: 555.27sec
# normalizedlinf
# 99: 555.07sec
# normalizedlinf
# 99: 555.76sec
# normalizedlinf
# 99: 540.33sec
# normalizedlinf
# 99: 529.24sec
# normalizedlinf
# 99: 524.44sec
# normalizedlinf
# 99: 523.82sec
# normalizedlinf
# 99: 524.23sec
# normalizedlinf
# 99: 523.94sec
# normalizedlinf
# 99: 525.23sec
# normalizedlinf
# 99: 524.44sec
# normalizedlinf
# 99: 524.37sec
# normalizedlinf
# 99: 524.98sec
# normalizedlinf
# 99: 524.53sec
# normalizedlinf
# 99: 524.52sec
# normalizedlinf
# 99: 524.31sec

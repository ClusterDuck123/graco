# %%
from pyclustering.cluster.kmedoids import kmedoids
from functools import partial
from random import sample

import os
import time
import numpy as np
import pandas as pd
import networkx as nx

# %%
DATA_DIRECTORY = "/media/clusterduck123/joe/data"
YEAST_DIRECTORY = f"{DATA_DIRECTORY}/processed-data/yeast"
NETWORK_DIRECTORY = f"{YEAST_DIRECTORY}/networks"
MATRIX_DIRECTORY  = f"{YEAST_DIRECTORY}/distance-matrices"
ANNOTATION_DIRECTORY = f"{YEAST_DIRECTORY}/annotations"

# %% [markdown]
# # Clustering

# %%
def get_number_of_pre_runs(CLUSTER_DIRECTORY, distance, n_clusters = 99):
    splitted_file_names = [name.split('_') for name in os.listdir(CLUSTER_DIRECTORY)]
    pre_runs = [int(run) for run, ncluster, db_txt in splitted_file_names if ncluster == str(n_clusters)]
    if pre_runs:
        return max(pre_runs)
    else:
        return -1

# %% [markdown]
# ## GDV

# %%
feature = 'GDV'

MIN_CLUSTERS = 2
MAX_CLUSTERS = 100

all_distances = sorted('_'.join(filename.split('_')[:-1]) 
                           for filename in os.listdir(f"{MATRIX_DIRECTORY}/{feature}"))

# %%
method = 'kmedoid'

for run in range(30):
    for distance in {'hellinger'}:
        print(distance)
        
        CLUSTER_DIRECTORY = f"{YEAST_DIRECTORY}/clusterings/{feature}/{distance}/{method}"
        if not os.path.exists(CLUSTER_DIRECTORY):
            os.makedirs(CLUSTER_DIRECTORY)
            
        df = pd.read_csv(f"{MATRIX_DIRECTORY}/{feature}/{distance}_BioGRID.txt", delimiter=' ')
        D  = df.values.astype(float) 

        t1 = time.time()
        for n_clusters in range(MIN_CLUSTERS, MAX_CLUSTERS+1):
            initial_medoids = sample(range(len(D)), n_clusters)
            kmedoids_instance = kmedoids(D, initial_medoids, data_type='distance_matrix')
            kmedoids_instance.process()
            
            nr = get_number_of_pre_runs(CLUSTER_DIRECTORY, distance, MAX_CLUSTERS)

            with open(f"{CLUSTER_DIRECTORY}/{nr+1}_{n_clusters}_BioGRID.txt", 'w') as f:
                for cluster in kmedoids_instance.get_clusters():
                    f.write(' '.join(df.columns[cluster]) + '\n')
            t2 = time.time()
            print(f'{n_clusters}: {t2-t1:.2f}sec', end='\r')
        print()
# Out:
# hellinger
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-09c9338601c2> in <module>
#       9             os.makedirs(CLUSTER_DIRECTORY)
#      10
# ---> 11         df = pd.read_csv(f"{MATRIX_DIRECTORY}/{feature}/{distance}_BioGRID.txt", delimiter=' ')
#      12         D  = df.values.astype(float)
#      13
#
# ~/Desktop/git/supplements/venv/graco/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~/Desktop/git/supplements/venv/graco/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/Desktop/git/supplements/venv/graco/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/Desktop/git/supplements/venv/graco/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~/Desktop/git/supplements/venv/graco/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'/media/clusterduck123/joe/data/processed-data/yeast/distance-matrices/GDV/hellinger_BioGRID.txt' does not exist: b'/media/clusterduck123/joe/data/processed-data/yeast/distance-matrices/GDV/hellinger_BioGRID.txt'

# %% [markdown]
# ## GCV-A

# %%
feature = 'GCV-A'

MIN_CLUSTERS = 2
MAX_CLUSTERS = 100

all_distances = sorted('_'.join(filename.split('_')[:-1]) 
                           for filename in os.listdir(f"{MATRIX_DIRECTORY}/{feature}"))

# %%
method = 'kmedoid'

for run in range(30):
    for distance in all_distances:
        print(distance)
        
        CLUSTER_DIRECTORY = f"{YEAST_DIRECTORY}/clusterings/{feature}/{distance}/{method}"
        if not os.path.exists(CLUSTER_DIRECTORY):
            os.makedirs(CLUSTER_DIRECTORY)
            
        df = pd.read_csv(f"{MATRIX_DIRECTORY}/{feature}/{distance}_BioGRID.txt", delimiter=' ')
        D  = df.values.astype(float) 

        t1 = time.time()
        for n_clusters in range(MIN_CLUSTERS, MAX_CLUSTERS+1):
            initial_medoids = sample(range(len(D)), n_clusters)
            kmedoids_instance = kmedoids(D, initial_medoids, data_type='distance_matrix')
            kmedoids_instance.process()
            
            nr = get_number_of_pre_runs(CLUSTER_DIRECTORY, distance, MAX_CLUSTERS)

            with open(f"{CLUSTER_DIRECTORY}/{nr+1}_{n_clusters}_BioGRID.txt", 'w') as f:
                for cluster in kmedoids_instance.get_clusters():
                    f.write(' '.join(df.columns[cluster]) + '\n')
            t2 = time.time()
            print(f'{n_clusters}: {t2-t1:.2f}sec', end='\r')
        print()
# Out:
# normalized1-linf
# 100: 567.56sec
# normalized1-l2
# 100: 553.66sec
# normalized1-l1
# 100: 568.33sec
# normalized1-linf
# 100: 566.88sec
# normalized1-l2
# 100: 543.78sec
# normalized1-l1
# 100: 542.83sec
# normalized1-linf
# 100: 562.03sec
# normalized1-l2
# 100: 561.84sec
# normalized1-l1
# 100: 565.90sec
# normalized1-linf
# 100: 585.38sec
# normalized1-l2
# 100: 553.77sec
# normalized1-l1
# 100: 569.14sec
# normalized1-linf
# 100: 544.02sec
# normalized1-l2
# 100: 557.46sec
# normalized1-l1
# 100: 550.29sec
# normalized1-linf
# 100: 561.53sec
# normalized1-l2
# 100: 546.45sec
# normalized1-l1
# 100: 565.12sec
# normalized1-linf
# 100: 555.60sec
# normalized1-l2
# 100: 548.69sec
# normalized1-l1
# 100: 579.96sec
# normalized1-linf
# 100: 568.23sec
# normalized1-l2
# 100: 558.88sec
# normalized1-l1
# 100: 575.31sec
# normalized1-linf
# 100: 552.40sec
# normalized1-l2
# 100: 550.22sec
# normalized1-l1
# 100: 570.18sec
# normalized1-linf
# 100: 589.95sec
# normalized1-l2
# 100: 594.89sec
# normalized1-l1
# 100: 600.24sec
# normalized1-linf
# 100: 591.80sec
# normalized1-l2
# 100: 576.68sec
# normalized1-l1
# 100: 600.33sec
# normalized1-linf
# 100: 579.74sec
# normalized1-l2
# 100: 589.04sec
# normalized1-l1
# 100: 605.94sec
# normalized1-linf
# 100: 576.16sec
# normalized1-l2
# 100: 582.09sec
# normalized1-l1
# 100: 623.37sec
# normalized1-linf
# 100: 605.80sec
# normalized1-l2
# 100: 601.76sec
# normalized1-l1
# 100: 621.67sec
# normalized1-linf
# 100: 605.21sec
# normalized1-l2
# 100: 603.54sec
# normalized1-l1
# 100: 607.22sec
# normalized1-linf
# 100: 603.71sec
# normalized1-l2
# 100: 601.16sec
# normalized1-l1
# 100: 613.27sec
# normalized1-linf
# 100: 610.51sec
# normalized1-l2
# 100: 600.49sec
# normalized1-l1
# 100: 603.19sec
# normalized1-linf
# 100: 609.79sec
# normalized1-l2
# 100: 598.49sec
# normalized1-l1
# 100: 606.13sec
# normalized1-linf
# 100: 611.47sec
# normalized1-l2
# 100: 604.88sec
# normalized1-l1
# 100: 602.60sec
# normalized1-linf
# 100: 609.47sec
# normalized1-l2
# 100: 599.80sec
# normalized1-l1
# 100: 613.32sec
# normalized1-linf
# 100: 604.82sec
# normalized1-l2
# 100: 600.13sec
# normalized1-l1
# 100: 619.02sec
# normalized1-linf
# 100: 599.87sec
# normalized1-l2
# 100: 598.86sec
# normalized1-l1
# 100: 622.18sec
# normalized1-linf
# 100: 594.47sec
# normalized1-l2
# 100: 602.70sec
# normalized1-l1
# 100: 612.16sec
# normalized1-linf
# 100: 610.14sec
# normalized1-l2
# 100: 600.80sec
# normalized1-l1
# 100: 625.80sec
# normalized1-linf
# 100: 610.94sec
# normalized1-l2
# 100: 602.27sec
# normalized1-l1
# 100: 614.08sec
# normalized1-linf
# 100: 602.53sec
# normalized1-l2
# 100: 598.38sec
# normalized1-l1
# 100: 607.15sec
# normalized1-linf
# 100: 609.22sec
# normalized1-l2
# 100: 599.97sec
# normalized1-l1
# 100: 613.66sec
# normalized1-linf
# 100: 609.92sec
# normalized1-l2
# 100: 598.88sec
# normalized1-l1
# 100: 604.45sec
# normalized1-linf
# 100: 611.63sec
# normalized1-l2
# 100: 603.19sec
# normalized1-l1
# 100: 624.35sec
# normalized1-linf
# 100: 605.05sec
# normalized1-l2
# 100: 601.79sec
# normalized1-l1
# 100: 625.59sec
# normalized1-linf
# 100: 600.77sec
# normalized1-l2
# 100: 596.41sec
# normalized1-l1
# 100: 611.99sec
# normalized1-linf
# 100: 612.23sec
# normalized1-l2
# 100: 596.56sec
# normalized1-l1
# 100: 614.23sec
# normalized1-linf
# 100: 609.06sec
# normalized1-l2
# 100: 604.03sec
# normalized1-l1
# 100: 560.15sec
# normalized1-linf
# 100: 557.21sec
# normalized1-l2
# 100: 552.48sec
# normalized1-l1
# 100: 559.74sec
# normalized1-linf
# 100: 561.37sec
# normalized1-l2
# 100: 552.93sec
# normalized1-l1
# 100: 560.18sec
# normalized1-linf
# 100: 558.31sec
# normalized1-l2
# 100: 546.69sec
# normalized1-l1
# 100: 567.09sec
# normalized1-linf
# 100: 562.88sec
# normalized1-l2
# 100: 548.73sec
# normalized1-l1
# 100: 565.21sec
# normalized1-linf
# 100: 559.56sec
# normalized1-l2
# 100: 551.87sec
# normalized1-l1
# 100: 559.50sec
# normalized1-linf
# 100: 566.21sec
# normalized1-l2
# 100: 589.19sec
# normalized1-l1
# 100: 608.29sec
# normalized1-linf
# 100: 581.74sec
# normalized1-l2
# 100: 591.30sec
# normalized1-l1
# 100: 586.87sec

# %% [markdown]
# ## GCV-G

# %%
feature = 'GCV-G'

MIN_CLUSTERS = 2
MAX_CLUSTERS = 100

all_distances = sorted('_'.join(filename.split('_')[:-1]) 
                           for filename in os.listdir(f"{MATRIX_DIRECTORY}/{feature}"))

# %%
method = 'kmedoid'

for run in range(30):
    for distance in all_distances:
        print(distance)
        
        CLUSTER_DIRECTORY = f"{YEAST_DIRECTORY}/clusterings/{feature}/{distance}/{method}"
        if not os.path.exists(CLUSTER_DIRECTORY):
            os.makedirs(CLUSTER_DIRECTORY)
            
        df = pd.read_csv(f"{MATRIX_DIRECTORY}/{feature}/{distance}_BioGRID.txt", delimiter=' ')
        D  = df.values.astype(float) 

        t1 = time.time()
        for n_clusters in range(MIN_CLUSTERS, MAX_CLUSTERS+1):
            initial_medoids = sample(range(len(D)), n_clusters)
            kmedoids_instance = kmedoids(D, initial_medoids, data_type='distance_matrix')
            kmedoids_instance.process()
            
            nr = get_number_of_pre_runs(CLUSTER_DIRECTORY, distance, MAX_CLUSTERS)

            with open(f"{CLUSTER_DIRECTORY}/{nr+1}_{n_clusters}_BioGRID.txt", 'w') as f:
                for cluster in kmedoids_instance.get_clusters():
                    f.write(' '.join(df.columns[cluster]) + '\n')
            t2 = time.time()
            print(f'{n_clusters}: {t2-t1:.2f}sec', end='\r')
        print()

# %% [markdown]
# # GCV-DA

# %%
feature = 'GCV-DA'

MIN_CLUSTERS = 2
MAX_CLUSTERS = 100

all_distances = sorted('_'.join(filename.split('_')[:-1]) 
                           for filename in os.listdir(f"{MATRIX_DIRECTORY}/{feature}"))

# %%
method = 'kmedoid'

for run in range(5):
    for distance in all_distances:
        print(distance)
        
        CLUSTER_DIRECTORY = f"{YEAST_DIRECTORY}/clusterings/{feature}/{distance}/{method}"
        if not os.path.exists(CLUSTER_DIRECTORY):
            os.makedirs(CLUSTER_DIRECTORY)
            
        df = pd.read_csv(f"{MATRIX_DIRECTORY}/{feature}/{distance}_BioGRID.txt", delimiter=' ')
        D  = df.values.astype(float) 

        t1 = time.time()
        for n_clusters in range(MIN_CLUSTERS, MAX_CLUSTERS+1):
            initial_medoids = sample(range(len(D)), n_clusters)
            kmedoids_instance = kmedoids(D, initial_medoids, data_type='distance_matrix')
            kmedoids_instance.process()
            
            nr = get_number_of_pre_runs(CLUSTER_DIRECTORY, distance, MAX_CLUSTERS)

            with open(f"{CLUSTER_DIRECTORY}/{nr+1}_{n_clusters}_BioGRID.txt", 'w') as f:
                for cluster in kmedoids_instance.get_clusters():
                    f.write(' '.join(df.columns[cluster]) + '\n')
            t2 = time.time()
            print(f'{n_clusters}: {t2-t1:.2f}sec', end='\r')
        print()
# Out:
# braycurtis
# 100: 655.56sec
# canberra
# 100: 648.68sec
# chebyshev
# 100: 684.83sec
# cityblock
# 100: 634.92sec
# correlation
# 100: 553.61sec
# cosine
# 100: 571.81sec
# euclidean
# 100: 580.79sec
# mahalanobis
# 100: 858.79sec
# normalized1_l1
# 100: 562.67sec
# normalized1_l2
# 100: 547.87sec
# normalized1_linf
# 100: 549.53sec
# normalized2_l1
# 100: 555.34sec
# normalized2_l2
# 100: 556.45sec
# normalized2_linf
# 100: 551.65sec
# seuclidean
# 100: 594.77sec
# sqeuclidean
# 100: 564.47sec
# braycurtis
# 100: 582.12sec
# canberra
# 100: 610.63sec
# chebyshev
# 100: 606.04sec
# cityblock
# 100: 598.08sec
# correlation
# 100: 624.48sec
# cosine
# 100: 604.16sec
# euclidean
# 100: 589.17sec
# mahalanobis
# 100: 839.64sec
# normalized1_l1
# 100: 577.07sec
# normalized1_l2
# 100: 596.52sec
# normalized1_linf
# 100: 578.79sec
# normalized2_l1
# 100: 558.39sec
# normalized2_l2
# 100: 566.19sec
# normalized2_linf
# 100: 596.35sec
# seuclidean
# 100: 586.19sec
# sqeuclidean
# 100: 639.95sec
# braycurtis
# 100: 617.50sec
# canberra
# 100: 605.71sec
# chebyshev
# 100: 581.36sec
# cityblock
# 100: 604.22sec
# correlation
# 100: 645.82sec
# cosine
# 100: 728.90sec
# euclidean
# 100: 678.92sec
# mahalanobis
# 100: 1032.27sec
# normalized1_l1
# 100: 702.89sec
# normalized1_l2
# 100: 582.89sec
# normalized1_linf
# 100: 570.16sec
# normalized2_l1
# 100: 562.87sec
# normalized2_l2
# 100: 623.41sec
# normalized2_linf
# 100: 581.25sec
# seuclidean
# 100: 629.78sec
# sqeuclidean
# 100: 618.10sec
# braycurtis
# 100: 580.32sec
# canberra
# 100: 578.27sec
# chebyshev
# 100: 600.07sec
# cityblock
# 100: 596.27sec
# correlation
# 100: 621.90sec
# cosine
# 100: 636.63sec
# euclidean
# 100: 637.17sec
# mahalanobis
# 100: 927.08sec
# normalized1_l1
# 100: 576.90sec
# normalized1_l2
# 100: 574.62sec
# normalized1_linf
# 100: 565.26sec
# normalized2_l1
# 100: 581.18sec
# normalized2_l2
# 100: 574.48sec
# normalized2_linf
# 100: 577.10sec
# seuclidean
# 100: 588.54sec
# sqeuclidean
# 100: 568.16sec
# braycurtis
# 100: 575.09sec
# canberra
# 100: 571.47sec
# chebyshev
# 100: 582.53sec
# cityblock
# 100: 574.65sec
# correlation
# 100: 598.04sec
# cosine
# 100: 580.34sec
# euclidean
# 100: 575.13sec
# mahalanobis
# 100: 888.11sec
# normalized1_l1
# 100: 568.59sec
# normalized1_l2
# 100: 566.91sec
# normalized1_linf
# 100: 564.80sec
# normalized2_l1
# 100: 574.32sec
# normalized2_l2
# 100: 566.59sec
# normalized2_linf
# 100: 590.40sec
# seuclidean
# 100: 577.37sec
# sqeuclidean
# 100: 568.09sec

# %% [markdown]
# # GCV-DG

# %%
feature = 'GCV-DG'

MIN_CLUSTERS = 2
MAX_CLUSTERS = 100

all_distances = sorted('_'.join(filename.split('_')[:-1]) 
                           for filename in os.listdir(f"{MATRIX_DIRECTORY}/{feature}"))

# %%
method = 'kmedoid'

for run in range(30):
    for distance in {'hellinger'}:
        print(distance)
        
        CLUSTER_DIRECTORY = f"{YEAST_DIRECTORY}/clusterings/{feature}/{distance}/{method}"
        if not os.path.exists(CLUSTER_DIRECTORY):
            os.makedirs(CLUSTER_DIRECTORY)
            
        df = pd.read_csv(f"{MATRIX_DIRECTORY}/{feature}/{distance}_BioGRID.txt", delimiter=' ')
        D  = df.values.astype(float) 

        t1 = time.time()
        for n_clusters in range(MIN_CLUSTERS, MAX_CLUSTERS+1):
            initial_medoids = sample(range(len(D)), n_clusters)
            kmedoids_instance = kmedoids(D, initial_medoids, data_type='distance_matrix')
            kmedoids_instance.process()
            
            nr = get_number_of_pre_runs(CLUSTER_DIRECTORY, distance, MAX_CLUSTERS)

            with open(f"{CLUSTER_DIRECTORY}/{nr+1}_{n_clusters}_BioGRID.txt", 'w') as f:
                for cluster in kmedoids_instance.get_clusters():
                    f.write(' '.join(df.columns[cluster]) + '\n')
            t2 = time.time()
            print(f'{n_clusters}: {t2-t1:.2f}sec', end='\r')
        print()
# Out:
# hellinger
# 100: 691.08sec
# hellinger
# 100: 758.33sec
# hellinger
# 100: 680.51sec
# hellinger
# 100: 670.54sec
# hellinger
# 100: 733.63sec
# hellinger
# 100: 675.36sec
# hellinger
# 100: 636.90sec
# hellinger
# 100: 607.97sec
# hellinger
# 100: 610.42sec
# hellinger
# 100: 617.80sec
# hellinger
# 100: 559.15sec
# hellinger
# 100: 553.84sec
# hellinger
# 100: 551.63sec
# hellinger
# 100: 548.57sec
# hellinger
# 100: 556.80sec
# hellinger
# 100: 553.30sec
# hellinger
# 100: 549.22sec
# hellinger
# 100: 563.44sec
# hellinger
# 100: 556.07sec
# hellinger
# 100: 544.23sec
# hellinger
# 100: 552.30sec
# hellinger
# 100: 557.16sec
# hellinger
# 100: 547.39sec
# hellinger
# 100: 556.67sec
# hellinger
# 100: 555.44sec
# hellinger
# 100: 543.67sec
# hellinger
# 100: 545.06sec
# hellinger
# 100: 555.96sec
# hellinger
# 100: 540.82sec
# hellinger
# 100: 536.18sec

# %% [markdown]
# ## GCV-all1

# %%
feature = 'GCV-all1'

MIN_CLUSTERS = 2
MAX_CLUSTERS = 100

all_distances = sorted('_'.join(filename.split('_')[:-1]) 
                           for filename in os.listdir(f"{MATRIX_DIRECTORY}/{feature}"))

# %%
method = 'kmedoid'

for run in range(10):
    for distance in all_distances:
        print(distance)
        
        CLUSTER_DIRECTORY = f"{YEAST_DIRECTORY}/clusterings/{feature}/{distance}/{method}"
        if not os.path.exists(CLUSTER_DIRECTORY):
            os.makedirs(CLUSTER_DIRECTORY)
            
        df = pd.read_csv(f"{MATRIX_DIRECTORY}/{feature}/{distance}_BioGRID.txt", delimiter=' ')
        D  = df.values.astype(float) 

        t1 = time.time()
        for n_clusters in range(MIN_CLUSTERS, MAX_CLUSTERS+1):
            initial_medoids = sample(range(len(D)), n_clusters)
            kmedoids_instance = kmedoids(D, initial_medoids, data_type='distance_matrix')
            kmedoids_instance.process()
            
            nr = get_number_of_pre_runs(CLUSTER_DIRECTORY, distance, MAX_CLUSTERS)

            with open(f"{CLUSTER_DIRECTORY}/{nr+1}_{n_clusters}_BioGRID.txt", 'w') as f:
                for cluster in kmedoids_instance.get_clusters():
                    f.write(' '.join(df.columns[cluster]) + '\n')
            t2 = time.time()
            print(f'{n_clusters}: {t2-t1:.2f}sec', end='\r')
        print()
# Out:
# braycurtis
# 100: 533.07sec
# canberra
# 100: 528.90sec
# chebyshev
# 100: 548.92sec
# cityblock
# 100: 531.91sec
# correlation
# 100: 530.68sec
# cosine
# 100: 542.59sec
# euclidean
# 100: 543.28sec
# hellinger
# 100: 532.75sec
# mahalanobis
# 100: 650.96sec
# normalized1_l1
# 100: 537.94sec
# normalized1_l2
# 100: 529.21sec
# normalized1_linf
# 100: 553.13sec
# normalized2_l1
# 100: 530.69sec
# normalized2_l2
# 100: 529.82sec
# normalized2_linf
# 100: 550.64sec
# seuclidean
# 100: 530.16sec
# sqeuclidean
# 100: 528.86sec
# braycurtis
# 100: 539.73sec
# canberra
# 100: 523.87sec
# chebyshev
# 100: 529.24sec
# cityblock
# 100: 536.14sec
# correlation
# 100: 542.37sec
# cosine
# 100: 524.20sec
# euclidean
# 100: 541.84sec
# hellinger
# 100: 538.05sec
# mahalanobis
# 100: 632.77sec
# normalized1_l1
# 100: 548.03sec
# normalized1_l2
# 100: 537.49sec
# normalized1_linf
# 100: 528.24sec
# normalized2_l1
# 100: 543.54sec
# normalized2_l2
# 100: 531.62sec
# normalized2_linf
# 100: 529.66sec
# seuclidean
# 100: 551.03sec
# sqeuclidean
# 100: 528.48sec
# braycurtis
# 100: 529.10sec
# canberra
# 100: 537.26sec
# chebyshev
# 100: 535.67sec
# cityblock
# 100: 529.49sec
# correlation
# 100: 535.17sec
# cosine
# 100: 534.85sec
# euclidean
# 100: 526.47sec
# hellinger
# 100: 530.93sec
# mahalanobis
# 100: 602.14sec
# normalized1_l1
# 100: 528.29sec
# normalized1_l2
# 100: 543.59sec
# normalized1_linf
# 100: 527.92sec
# normalized2_l1
# 100: 526.85sec
# normalized2_l2
# 100: 527.86sec
# normalized2_linf
# 100: 535.94sec
# seuclidean
# 100: 530.32sec
# sqeuclidean
# 100: 537.19sec
# braycurtis
# 100: 529.75sec
# canberra
# 100: 528.88sec
# chebyshev
# 100: 543.88sec
# cityblock
# 100: 532.16sec
# correlation
# 100: 529.13sec
# cosine
# 100: 546.31sec
# euclidean
# 100: 533.32sec
# hellinger
# 100: 529.06sec
# mahalanobis
# 100: 652.91sec
# normalized1_l1
# 100: 534.77sec
# normalized1_l2
# 100: 527.48sec
# normalized1_linf
# 100: 544.44sec
# normalized2_l1
# 100: 536.18sec
# normalized2_l2
# 100: 528.52sec
# normalized2_linf
# 100: 536.92sec
# seuclidean
# 100: 535.46sec
# sqeuclidean
# 100: 527.15sec
# braycurtis
# 100: 536.29sec
# canberra
# 100: 531.53sec
# chebyshev
# 100: 526.10sec
# cityblock
# 100: 536.84sec
# correlation
# 100: 539.23sec
# cosine
# 100: 523.13sec
# euclidean
# 100: 541.09sec
# hellinger
# 100: 533.11sec
# mahalanobis
# 100: 646.30sec
# normalized1_l1
# 100: 540.91sec
# normalized1_l2
# 100: 542.62sec
# normalized1_linf
# 30: 164.51sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-71f00b668966> in <module>
#      16             initial_medoids = sample(range(len(D)), n_clusters)
#      17             kmedoids_instance = kmedoids(D, initial_medoids, data_type='distance_matrix')
# ---> 18             kmedoids_instance.process()
#      19
#      20             nr = get_number_of_pre_runs(CLUSTER_DIRECTORY, distance, MAX_CLUSTERS)
#
# ~/Desktop/git/supplements/venv/graco/lib/python3.6/site-packages/pyclustering/cluster/kmedoids.py in process(self)
#     156         if self.__ccore is True:
#     157             ccore_metric = metric_wrapper.create_instance(self.__metric)
# --> 158             self.__clusters, self.__medoid_indexes = wrapper.kmedoids(self.__pointer_data, self.__medoid_indexes, self.__tolerance, self.__itermax, ccore_metric.get_pointer(), self.__data_type)
#     159
#     160         else:
#
# ~/Desktop/git/supplements/venv/graco/lib/python3.6/site-packages/pyclustering/core/kmedoids_wrapper.py in kmedoids(sample, medoids, tolerance, itermax, metric_pointer, data_type)
#      33
#      34 def kmedoids(sample, medoids, tolerance, itermax, metric_pointer, data_type):
# ---> 35     pointer_data = package_builder(sample, c_double).create()
#      36     medoids_package = package_builder(medoids, c_size_t).create()
#      37     c_data_type = convert_data_type(data_type)
#
# ~/Desktop/git/supplements/venv/graco/lib/python3.6/site-packages/pyclustering/core/pyclustering_package.py in create(self)
#     132
#     133         """
# --> 134         return self.__create_package(self.__dataset)
#     135
#     136
#
# ~/Desktop/git/supplements/venv/graco/lib/python3.6/site-packages/pyclustering/core/pyclustering_package.py in __create_package(self, dataset)
#     161
#     162         c_data_type = self.__fill_type(dataset_package, dataset)
# --> 163         self.__fill_data(dataset_package, c_data_type, dataset)
#     164
#     165         return pointer(dataset_package)
#
# ~/Desktop/git/supplements/venv/graco/lib/python3.6/site-packages/pyclustering/core/pyclustering_package.py in __fill_data(self, dataset_package, c_data_type, dataset)
#     202             package_data = (POINTER(pyclustering_package) * len(dataset))()
#     203             for index in range(len(dataset)):
# --> 204                 package_data[index] = self.__create_package(dataset[index])
#     205
#     206             dataset_package.data = cast(package_data, POINTER(c_void_p))
#
# ~/Desktop/git/supplements/venv/graco/lib/python3.6/site-packages/pyclustering/core/pyclustering_package.py in __create_package(self, dataset)
#     161
#     162         c_data_type = self.__fill_type(dataset_package, dataset)
# --> 163         self.__fill_data(dataset_package, c_data_type, dataset)
#     164
#     165         return pointer(dataset_package)
#
# ~/Desktop/git/supplements/venv/graco/lib/python3.6/site-packages/pyclustering/core/pyclustering_package.py in __fill_data(self, dataset_package, c_data_type, dataset)
#     206             dataset_package.data = cast(package_data, POINTER(c_void_p))
#     207         else:
# --> 208             array_object = (c_data_type * len(dataset))(*dataset)
#     209             dataset_package.data = cast(array_object, POINTER(c_void_p))
#     210
#
# KeyboardInterrupt:

# %% [markdown]
# ## GCV-all2

# %%
feature = 'GCV-all2'

MIN_CLUSTERS = 2
MAX_CLUSTERS = 100

all_distances = sorted('_'.join(filename.split('_')[:-1]) 
                           for filename in os.listdir(f"{MATRIX_DIRECTORY}/{feature}"))

# %%
method = 'kmedoid'

for run in range(10):
    for distance in {'canberra'}:
        print(distance)
        
        CLUSTER_DIRECTORY = f"{YEAST_DIRECTORY}/clusterings/{feature}/{distance}/{method}"
        if not os.path.exists(CLUSTER_DIRECTORY):
            os.makedirs(CLUSTER_DIRECTORY)
            
        df = pd.read_csv(f"{MATRIX_DIRECTORY}/{feature}/{distance}_BioGRID.txt", delimiter=' ')
        D  = df.values.astype(float) 

        t1 = time.time()
        for n_clusters in range(MIN_CLUSTERS, MAX_CLUSTERS+1):
            initial_medoids = sample(range(len(D)), n_clusters)
            kmedoids_instance = kmedoids(D, initial_medoids, data_type='distance_matrix')
            kmedoids_instance.process()
            
            nr = get_number_of_pre_runs(CLUSTER_DIRECTORY, distance, MAX_CLUSTERS)

            with open(f"{CLUSTER_DIRECTORY}/{nr+1}_{n_clusters}_BioGRID.txt", 'w') as f:
                for cluster in kmedoids_instance.get_clusters():
                    f.write(' '.join(df.columns[cluster]) + '\n')
            t2 = time.time()
            print(f'{n_clusters}: {t2-t1:.2f}sec', end='\r')
        print()
# Out:
# canberra
# 100: 562.88sec
# canberra
# 100: 580.86sec
# canberra
# 100: 557.69sec
# canberra
# 100: 554.52sec
# canberra
# 100: 568.93sec
# canberra
# 100: 568.95sec
# canberra
# 100: 593.80sec
# canberra
# 100: 558.38sec
# canberra
# 100: 559.47sec
# canberra
# 100: 526.38sec

# %% [markdown]
# ## GCV-orca

# %%
feature = 'GCV-orca'

MIN_CLUSTERS = 2
MAX_CLUSTERS = 100

all_distances = sorted('_'.join(filename.split('_')[:-1]) 
                           for filename in os.listdir(f"{MATRIX_DIRECTORY}/{feature}"))

# %%
method = 'kmedoid'

for run in range(10):
    for distance in {'canberra'}:
        print(distance)
        
        CLUSTER_DIRECTORY = f"{YEAST_DIRECTORY}/clusterings/{feature}/{distance}/{method}"
        if not os.path.exists(CLUSTER_DIRECTORY):
            os.makedirs(CLUSTER_DIRECTORY)
            
        df = pd.read_csv(f"{MATRIX_DIRECTORY}/{feature}/{distance}_BioGRID.txt", delimiter=' ')
        D  = df.values.astype(float) 

        t1 = time.time()
        for n_clusters in range(MIN_CLUSTERS, MAX_CLUSTERS+1):
            initial_medoids = sample(range(len(D)), n_clusters)
            kmedoids_instance = kmedoids(D, initial_medoids, data_type='distance_matrix')
            kmedoids_instance.process()
            
            nr = get_number_of_pre_runs(CLUSTER_DIRECTORY, distance, MAX_CLUSTERS)

            with open(f"{CLUSTER_DIRECTORY}/{nr+1}_{n_clusters}_BioGRID.txt", 'w') as f:
                for cluster in kmedoids_instance.get_clusters():
                    f.write(' '.join(df.columns[cluster]) + '\n')
            t2 = time.time()
            print(f'{n_clusters}: {t2-t1:.2f}sec', end='\r')
        print()
# Out:
# canberra
# 100: 535.50sec
# canberra
# 100: 536.39sec
# canberra
# 100: 524.62sec
# canberra
# 100: 540.29sec
# canberra
# 100: 524.23sec
# canberra
# 100: 525.40sec
# canberra
# 100: 533.61sec
# canberra
# 100: 539.02sec
# canberra
# 100: 529.45sec
# canberra
# 100: 545.67sec

# %% [markdown]
# ## GCV-orca+

# %%
feature = 'GCV-orca+'

MIN_CLUSTERS = 2
MAX_CLUSTERS = 100

all_distances = sorted('_'.join(filename.split('_')[:-1]) 
                           for filename in os.listdir(f"{MATRIX_DIRECTORY}/{feature}"))

# %%
method = 'kmedoid'

for run in range(10):
    for distance in {'canberra'}:
        print(distance)
        
        CLUSTER_DIRECTORY = f"{YEAST_DIRECTORY}/clusterings/{feature}/{distance}/{method}"
        if not os.path.exists(CLUSTER_DIRECTORY):
            os.makedirs(CLUSTER_DIRECTORY)
            
        df = pd.read_csv(f"{MATRIX_DIRECTORY}/{feature}/{distance}_BioGRID.txt", delimiter=' ')
        D  = df.values.astype(float) 

        t1 = time.time()
        for n_clusters in range(MIN_CLUSTERS, MAX_CLUSTERS+1):
            initial_medoids = sample(range(len(D)), n_clusters)
            kmedoids_instance = kmedoids(D, initial_medoids, data_type='distance_matrix')
            kmedoids_instance.process()
            
            nr = get_number_of_pre_runs(CLUSTER_DIRECTORY, distance, MAX_CLUSTERS)

            with open(f"{CLUSTER_DIRECTORY}/{nr+1}_{n_clusters}_BioGRID.txt", 'w') as f:
                for cluster in kmedoids_instance.get_clusters():
                    f.write(' '.join(df.columns[cluster]) + '\n')
            t2 = time.time()
            print(f'{n_clusters}: {t2-t1:.2f}sec', end='\r')
        print()
# Out:
# canberra
# 100: 568.72sec
# canberra
# 100: 567.64sec
# canberra
# 100: 570.65sec
# canberra
# 100: 552.77sec
# canberra
# 100: 553.76sec
# canberra
# 100: 542.94sec
# canberra
# 100: 535.07sec
# canberra
# 100: 552.04sec
# canberra
# 100: 554.58sec
# canberra
# 100: 531.31sec

# %%
from scipy.spatial.distance import squareform, cdist
from itertools import combinations
from functools import partial

import networkx as nx
import pandas as pd
import numpy as np
import graco
import os

# %%
G = nx.erdos_renyi_graph(100,0.1)
A = nx.to_numpy_array(G)
GDV = graco.orbits(G)

# %%
(1*GDV['4'] + 2*GDV['8'] + 1*GDV['10'] + 2*GDV['13'] == A@GDV['1'] - 2*GDV['2']).all()
# Out:
# True

# %%
(GDV['1'] + 2*GDV['3'] == A@GDV['0'] - GDV['0']).all()
# Out:
# True

# %%
(1*GDV['6'] + 1*GDV['10'] + 1*GDV['13'] == A@GDV['2'] - GDV['1']).all()
# Out:
# True

# %%
(1*GDV['9'] + 2*GDV['12'] + 3*GDV['14'] == A@GDV['3'] - 2*GDV['3']).all()
# Out:
# True

# %%
np.savetxt(MATRIX_IN,
           GCV,
           header=' '.join(map(str,GCV.shape)),
           fmt='%.7f')

# %%
D2 = graco.distances.GDV_similarity(GCV)

# %%
def normalized1_lp(P,Q,p=1):
    v1 = np.divide(P, P+Q, out=np.zeros_like(P), where=(P+Q)!=0)
    v2 = np.divide(Q, P+Q, out=np.zeros_like(Q), where=(P+Q)!=0)
    return np.linalg.norm(v1-v2,p)

# %%
GDV = np.random.randint(100, size=[100,15])
GDV[0,1] = 0
GDV[1,1] = 0

# %%
D1 = cdist(GDV.astype(float),
           GDV.astype(float),
           partial(normalized1_lp, p=np.inf))
D2 = graco.distances.normalized1_lp(GDV, np.inf)

# %%
pd.DataFrame(D2)
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.000000  0.846154  1.000000  1.000000  1.000000  1.000000  1.000000
# 1   0.846154  0.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 2   1.000000  1.000000  0.000000  0.800000  0.897959  0.935484  0.809524
# 3   1.000000  1.000000  0.800000  0.000000  0.880952  0.952941  0.733333
# 4   1.000000  1.000000  0.897959  0.880952  0.000000  0.951807  0.811321
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  1.000000  1.000000  0.796610  0.729167  0.888889  0.881188  0.813084
# 96  1.000000  1.000000  0.643836  0.747368  0.883721  0.780220  0.763636
# 97  1.000000  1.000000  0.934066  0.886792  0.877551  0.934783  0.933333
# 98  1.000000  1.000000  0.764706  0.753425  0.880952  0.944444  0.847619
# 99  1.000000  1.000000  0.827586  0.908046  0.905882  0.921053  0.870968
#
#           7         8         9   ...        90        91   92        93  \
# ...

# %%
pd.DataFrame(D1)
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.000000  0.846154  1.000000  1.000000  1.000000  1.000000  1.000000
# 1   0.846154  0.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 2   1.000000  1.000000  0.000000  0.800000  0.897959  0.935484  0.809524
# 3   1.000000  1.000000  0.800000  0.000000  0.880952  0.952941  0.733333
# 4   1.000000  1.000000  0.897959  0.880952  0.000000  0.951807  0.811321
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  1.000000  1.000000  0.796610  0.729167  0.888889  0.881188  0.813084
# 96  1.000000  1.000000  0.643836  0.747368  0.883721  0.780220  0.763636
# 97  1.000000  1.000000  0.934066  0.886792  0.877551  0.934783  0.933333
# 98  1.000000  1.000000  0.764706  0.753425  0.880952  0.944444  0.847619
# 99  1.000000  1.000000  0.827586  0.908046  0.905882  0.921053  0.870968
#
#           7         8         9   ...        90        91   92        93  \
# ...

# %%
np.argmax(abs(D1-D2))
# Out:
# 2345

# %%
D1[23,45],D2[23,45]
# Out:
# (1.0, 0.45)

# %%
P, Q = GDV[23], GDV[45]

# %%
np.nanmax(np.abs(P-Q)/(P+Q))
# Out:
# /home/clusterduck123/Desktop/git/supplements/venv/graco/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.
# 1.0

# %%
np.max([P-Q])
# Out:
# 91

# %%
abs(P-Q)/(P+Q)
# Out:
# /home/clusterduck123/Desktop/git/supplements/venv/graco/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.
# array([0.15584416, 0.14473684, 0.38636364, 0.5959596 , 0.83333333,
#        1.        , 1.        ,        nan, 0.33928571, 0.23880597,
#        0.44186047, 0.06432749, 0.43478261, 0.45      , 0.06896552])

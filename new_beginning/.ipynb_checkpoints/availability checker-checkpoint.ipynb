# %%
import os
import pandas as pd

DATA_DIRECTORY = "/media/clusterduck123/joe/data"
RAW_DATA_DIRECTORY = f"{DATA_DIRECTORY}/raw-data"
YEAST_DIRECTORY = f"{DATA_DIRECTORY}/processed-data/organisms/yeast"
HUMAN_DIRECTORY = f"{DATA_DIRECTORY}/processed-data/organisms/human"

# %%
def get_maxrun(DIRECTORY):
    splitted_file_names = [name.split('_') for name in os.listdir(DIRECTORY)]
    pre_runs = [int(run) for run, ncluster, db_txt in splitted_file_names]
    if pre_runs:
        return max(pre_runs)
    else:
        return 0

# %% [markdown]
# # Yeast

# %% [markdown]
# ## Clusters

# %%
CLUSTER_DIRECTORY = f"{YEAST_DIRECTORY}/clusterings"

for feature in os.listdir(CLUSTER_DIRECTORY):
    for distance in os.listdir(f"{CLUSTER_DIRECTORY}/{feature}"):
        maxrun = get_maxrun(f"{CLUSTER_DIRECTORY}/{feature}/{distance}/kmedoid")
        print(feature, distance, maxrun)
    print()
# Out:
# GCV-DG normalized1-l1 44
# GCV-DG normalized2-l2 5
# GCV-DG normalized2-l1 5
# GCV-DG normalized1-l2 45
# GCV-DG normalized1-linf 45
# GCV-DG normalized2-linf 5
#
# GCV-G normalized1-l1 49
# GCV-G normalized1-l2 49
# GCV-G normalized1-linf 49
#
# GCV-D0 normalized1-l1 9
# GCV-D0 cosine 8
# GCV-D0 euclidean 8
# GCV-D0 cityblock 8
# GCV-D0 canberra 9
# GCV-D0 normalized1-l2 8
# GCV-D0 correlation 8
# GCV-D0 normalized1-linf 8
# GCV-D0 chebyshev 9
# GCV-D0 braycurtis 9
# GCV-D0 sqeuclidean 9
#
# GCV-A normalized1-l1 49
# GCV-A normalized1-l2 49
# GCV-A normalized1-linf 49
#
# GCV-AD normalized1-l1 46
# GCV-AD normalized1-l2 47
# GCV-AD normalized1-linf 47
#
# GDV normalized1-l1 35
# GDV cosine 35
# GDV euclidean 36
# GDV seuclidean 35
# GDV normalized2-l2 29
# GDV normalized2-l1 29
# GDV cityblock 35
# GDV canberra 35
# GDV normalized1-l2 35
# GDV mahalanobis 36
# GDV correlation 35
# GDV GDV-similarity 36
# GDV normalized1-linf 35
# GDV chebyshev 35
# GDV normalized2-linf 29
# GDV braycurtis 35
# GDV sqeuclidean 35

# %% [markdown]
# # p-values

# %%
CLUSTER_DIRECTORY = f"{YEAST_DIRECTORY}/p-values"

for feature in os.listdir(CLUSTER_DIRECTORY):
    for distance in os.listdir(  f"{CLUSTER_DIRECTORY}/{feature}"):
        for aspect in os.listdir(f"{CLUSTER_DIRECTORY}/{feature}/{distance}/kmedoid"):
            maxrun = get_maxrun( f"{CLUSTER_DIRECTORY}/{feature}/{distance}/kmedoid/{aspect}")
            print(feature.ljust(6), distance.ljust(16), aspect, maxrun)
        print()
    print()
# Out:
# GCV-DG normalized1-l1   BP 29
# GCV-DG normalized1-l1   MF 29
# GCV-DG normalized1-l1   CC 29
#
# GCV-DG normalized1-l2   BP 29
# GCV-DG normalized1-l2   MF 29
# GCV-DG normalized1-l2   CC 29
#
# GCV-DG normalized1-linf BP 29
# GCV-DG normalized1-linf MF 29
# GCV-DG normalized1-linf CC 29
#
#
# GCV-G  normalized1-l1   BP 29
# GCV-G  normalized1-l1   MF 29
# GCV-G  normalized1-l1   CC 29
#
# GCV-G  normalized1-l2   BP 29
# GCV-G  normalized1-l2   MF 29
# GCV-G  normalized1-l2   CC 29
#
# GCV-G  normalized1-linf BP 29
# GCV-G  normalized1-linf MF 29
# GCV-G  normalized1-linf CC 29
#
#
# GCV-A  normalized1-l1   BP 29
# GCV-A  normalized1-l1   MF 29
# GCV-A  normalized1-l1   CC 29
#
# GCV-A  normalized1-l2   BP 29
# GCV-A  normalized1-l2   MF 29
# GCV-A  normalized1-l2   CC 29
#
# GCV-A  normalized1-linf BP 29
# GCV-A  normalized1-linf MF 29
# GCV-A  normalized1-linf CC 29
#
#
# GCV-AD normalized1-l1   BP 29
# GCV-AD normalized1-l1   MF 29
# GCV-AD normalized1-l1   CC 29
#
# GCV-AD normalized1-l2   BP 29
# GCV-AD normalized1-l2   MF 29
# GCV-AD normalized1-l2   CC 29
#
# GCV-AD normalized1-linf BP 29
# GCV-AD normalized1-linf MF 29
# GCV-AD normalized1-linf CC 29
#
#
# GDV    normalized1-l1   BP 29
# GDV    normalized1-l1   MF 29
# GDV    normalized1-l1   CC 29
#
# GDV    cosine           BP 29
# GDV    cosine           MF 29
# GDV    cosine           CC 29
#
# GDV    euclidean        BP 29
# GDV    euclidean        MF 36
# GDV    euclidean        CC 29
#
# GDV    seuclidean       BP 29
# GDV    seuclidean       MF 29
# GDV    seuclidean       CC 29
#
# GDV    normalized2-l2   BP 29
# GDV    normalized2-l2   MF 29
# GDV    normalized2-l2   CC 29
#
# GDV    normalized2-l1   BP 14
# GDV    normalized2-l1   MF 29
# GDV    normalized2-l1   CC 29
#
# GDV    cityblock        BP 29
# GDV    cityblock        MF 35
# GDV    cityblock        CC 29
#
# GDV    canberra         BP 29
# GDV    canberra         MF 29
# GDV    canberra         CC 29
#
# GDV    normalized1-l2   BP 29
# GDV    normalized1-l2   MF 29
# GDV    normalized1-l2   CC 29
#
# GDV    mahalanobis      BP 29
# GDV    mahalanobis      MF 29
# GDV    mahalanobis      CC 29
#
# GDV    correlation      BP 29
# GDV    correlation      MF 29
# GDV    correlation      CC 29
#
# GDV    GDV-similarity   BP 29
# GDV    GDV-similarity   MF 29
# GDV    GDV-similarity   CC 29
#
# GDV    normalized1-linf BP 29
# GDV    normalized1-linf MF 29
# GDV    normalized1-linf CC 29
#
# GDV    chebyshev        BP 29
# GDV    chebyshev        MF 35
# GDV    chebyshev        CC 29
#
# GDV    normalized2-linf BP 29
# GDV    normalized2-linf MF 29
# GDV    normalized2-linf CC 29
#
# GDV    braycurtis       BP 29
# GDV    braycurtis       MF 29
# GDV    braycurtis       CC 29
#
# GDV    sqeuclidean      BP 29
# GDV    sqeuclidean      MF 29
# GDV    sqeuclidean      CC 29

# %% [markdown]
# # Enrichment

# %%
ENRICHMENT_DIRECTORY = f"{YEAST_DIRECTORY}/enrichments"

for feature in os.listdir(ENRICHMENT_DIRECTORY):
    for distance in sorted(os.listdir(          f"{ENRICHMENT_DIRECTORY}/{feature}")):
        for aspect in os.listdir(        f"{ENRICHMENT_DIRECTORY}/{feature}/{distance}/kmedoid"):
            for correction in os.listdir(f"{ENRICHMENT_DIRECTORY}/{feature}/{distance}/kmedoid/{aspect}"):
                with open(               f"{ENRICHMENT_DIRECTORY}/{feature}/{distance}/kmedoid/{aspect}/"
                                         f"{correction}/clusters.csv", 'r') as f:
                    l1 = len(f.readline().strip(',\n').split(','))
                with open(               f"{ENRICHMENT_DIRECTORY}/{feature}/{distance}/kmedoid/{aspect}/"
                                         f"{correction}/GO-terms.csv", 'r') as f:
                    l2 = len(f.readline().strip(',\n').split(','))
                with open(               f"{ENRICHMENT_DIRECTORY}/{feature}/{distance}/kmedoid/{aspect}/"
                                         f"{correction}/genes.csv", 'r') as f:
                    l3 = len(f.readline().strip(',\n').split(','))

                print(feature.ljust(6), distance.ljust(16), aspect, correction, (l1+l2+l3)/3)
        print()
    print()
# Out:
# GCV-DG normalized1-l1   BP BH 30.0
# GCV-DG normalized1-l1   BP BY 30.0
# GCV-DG normalized1-l1   MF BH 30.0
# GCV-DG normalized1-l1   MF BY 30.0
# GCV-DG normalized1-l1   CC BH 30.0
# GCV-DG normalized1-l1   CC BY 30.0
#
# GCV-DG normalized1-l2   BP BH 30.0
# GCV-DG normalized1-l2   BP BY 30.0
# GCV-DG normalized1-l2   MF BH 30.0
# GCV-DG normalized1-l2   MF BY 30.0
# GCV-DG normalized1-l2   CC BH 30.0
# GCV-DG normalized1-l2   CC BY 30.0
#
# GCV-DG normalized1-linf BP BH 30.0
# GCV-DG normalized1-linf BP BY 30.0
# GCV-DG normalized1-linf MF BH 30.0
# GCV-DG normalized1-linf MF BY 30.0
# GCV-DG normalized1-linf CC BH 30.0
# GCV-DG normalized1-linf CC BY 30.0
#
#
# GCV-G  normalized1-l1   BP BH 30.0
# GCV-G  normalized1-l1   BP BY 30.0
# GCV-G  normalized1-l1   MF BH 30.0
# GCV-G  normalized1-l1   MF BY 30.0
# GCV-G  normalized1-l1   CC BH 30.0
# GCV-G  normalized1-l1   CC BY 30.0
#
# GCV-G  normalized1-l2   BP BH 30.0
# GCV-G  normalized1-l2   BP BY 30.0
# GCV-G  normalized1-l2   MF BH 30.0
# GCV-G  normalized1-l2   MF BY 30.0
# GCV-G  normalized1-l2   CC BH 30.0
# GCV-G  normalized1-l2   CC BY 30.0
#
# GCV-G  normalized1-linf BP BH 30.0
# GCV-G  normalized1-linf BP BY 30.0
# GCV-G  normalized1-linf MF BH 30.0
# GCV-G  normalized1-linf MF BY 30.0
# GCV-G  normalized1-linf CC BH 30.0
# GCV-G  normalized1-linf CC BY 30.0
#
#
# GCV-A  normalized1-l1   BP BH 30.0
# GCV-A  normalized1-l1   BP BY 30.0
# GCV-A  normalized1-l1   MF BH 30.0
# GCV-A  normalized1-l1   MF BY 30.0
# GCV-A  normalized1-l1   CC BH 30.0
# GCV-A  normalized1-l1   CC BY 30.0
#
# GCV-A  normalized1-l2   BP BH 30.0
# GCV-A  normalized1-l2   BP BY 30.0
# GCV-A  normalized1-l2   MF BH 30.0
# GCV-A  normalized1-l2   MF BY 30.0
# GCV-A  normalized1-l2   CC BH 30.0
# GCV-A  normalized1-l2   CC BY 30.0
#
# GCV-A  normalized1-linf BP BH 30.0
# GCV-A  normalized1-linf BP BY 30.0
# GCV-A  normalized1-linf MF BH 30.0
# GCV-A  normalized1-linf MF BY 30.0
# GCV-A  normalized1-linf CC BH 30.0
# GCV-A  normalized1-linf CC BY 30.0
#
#
# GCV-AD normalized1-l1   BP BH 30.0
# GCV-AD normalized1-l1   BP BY 30.0
# GCV-AD normalized1-l1   MF BH 30.0
# GCV-AD normalized1-l1   MF BY 30.0
# GCV-AD normalized1-l1   CC BH 30.0
# GCV-AD normalized1-l1   CC BY 30.0
#
# GCV-AD normalized1-l2   BP BH 30.0
# GCV-AD normalized1-l2   BP BY 30.0
# GCV-AD normalized1-l2   MF BH 30.0
# GCV-AD normalized1-l2   MF BY 30.0
# GCV-AD normalized1-l2   CC BH 30.0
# GCV-AD normalized1-l2   CC BY 30.0
#
# GCV-AD normalized1-linf BP BH 30.0
# GCV-AD normalized1-linf BP BY 30.0
# GCV-AD normalized1-linf MF BH 30.0
# GCV-AD normalized1-linf MF BY 30.0
# GCV-AD normalized1-linf CC BH 30.0
# GCV-AD normalized1-linf CC BY 30.0
#
#
# GDV    GDV-similarity   BP BH 30.0
# GDV    GDV-similarity   BP BY 30.0
# GDV    GDV-similarity   MF BH 30.0
# GDV    GDV-similarity   MF BY 30.0
# GDV    GDV-similarity   CC BH 30.0
# GDV    GDV-similarity   CC BY 30.0
#
# GDV    braycurtis       BP BH 30.0
# GDV    braycurtis       BP BY 30.0
# GDV    braycurtis       MF BH 30.0
# GDV    braycurtis       MF BY 30.0
# GDV    braycurtis       CC BH 30.0
# GDV    braycurtis       CC BY 30.0
#
# GDV    canberra         BP BH 30.0
# GDV    canberra         BP BY 30.0
# GDV    canberra         MF BH 30.0
# GDV    canberra         MF BY 30.0
# GDV    canberra         CC BH 30.0
# GDV    canberra         CC BY 30.0
#
# GDV    chebyshev        BP BH 30.0
# GDV    chebyshev        BP BY 30.0
# GDV    chebyshev        MF BH 30.0
# GDV    chebyshev        MF BY 30.0
# GDV    chebyshev        CC BH 30.0
# GDV    chebyshev        CC BY 30.0
#
# GDV    cityblock        BP BH 30.0
# GDV    cityblock        BP BY 30.0
# GDV    cityblock        MF BH 30.0
# GDV    cityblock        MF BY 30.0
# GDV    cityblock        CC BH 30.0
# GDV    cityblock        CC BY 30.0
#
# GDV    correlation      BP BH 30.0
# GDV    correlation      BP BY 30.0
# GDV    correlation      MF BH 30.0
# GDV    correlation      MF BY 30.0
# GDV    correlation      CC BH 30.0
# GDV    correlation      CC BY 30.0
#
# GDV    cosine           BP BH 30.0
# GDV    cosine           BP BY 30.0
# GDV    cosine           MF BH 30.0
# GDV    cosine           MF BY 30.0
# GDV    cosine           CC BH 30.0
# GDV    cosine           CC BY 30.0
#
# GDV    euclidean        BP BH 30.0
# GDV    euclidean        BP BY 30.0
# GDV    euclidean        MF BH 30.0
# GDV    euclidean        MF BY 30.0
# GDV    euclidean        CC BH 30.0
# GDV    euclidean        CC BY 30.0
#
# GDV    mahalanobis      BP BH 30.0
# GDV    mahalanobis      BP BY 30.0
# GDV    mahalanobis      MF BH 30.0
# GDV    mahalanobis      MF BY 30.0
# GDV    mahalanobis      CC BH 30.0
# GDV    mahalanobis      CC BY 30.0
#
# GDV    normalized1-l1   BP BH 30.0
# GDV    normalized1-l1   BP BY 30.0
# GDV    normalized1-l1   MF BH 30.0
# GDV    normalized1-l1   MF BY 30.0
# GDV    normalized1-l1   CC BH 30.0
# GDV    normalized1-l1   CC BY 30.0
#
# GDV    normalized1-l2   BP BH 30.0
# GDV    normalized1-l2   BP BY 30.0
# GDV    normalized1-l2   MF BH 30.0
# GDV    normalized1-l2   MF BY 30.0
# GDV    normalized1-l2   CC BH 30.0
# GDV    normalized1-l2   CC BY 30.0
#
# GDV    normalized1-linf BP BH 30.0
# GDV    normalized1-linf BP BY 30.0
# GDV    normalized1-linf MF BH 30.0
# GDV    normalized1-linf MF BY 30.0
# GDV    normalized1-linf CC BH 30.0
# GDV    normalized1-linf CC BY 30.0
#
# GDV    seuclidean       BP BH 30.0
# GDV    seuclidean       BP BY 30.0
# GDV    seuclidean       MF BH 30.0
# GDV    seuclidean       MF BY 30.0
# GDV    seuclidean       CC BH 30.0
# GDV    seuclidean       CC BY 30.0
#
# GDV    sqeuclidean      BP BH 30.0
# GDV    sqeuclidean      BP BY 30.0
# GDV    sqeuclidean      MF BH 30.0
# GDV    sqeuclidean      MF BY 30.0
# GDV    sqeuclidean      CC BH 30.0
# GDV    sqeuclidean      CC BY 30.0

# %% [markdown]
# # Human

# %% [markdown]
# ## Clusters

# %%
CLUSTER_DIRECTORY = f"{HUMAN_DIRECTORY}/clusterings"

for feature in os.listdir(CLUSTER_DIRECTORY):
    for distance in os.listdir(f"{CLUSTER_DIRECTORY}/{feature}"):
        maxrun = get_maxrun(f"{CLUSTER_DIRECTORY}/{feature}/{distance}/kmedoid")
        print(feature, distance, maxrun)
    print()
# Out:
# GDV normalized1-l1 14
# GDV cosine 0
# GDV euclidean 0
# GDV normalized1-l2 15
# GDV mahalanobis 17
# GDV GDV-similarity 16
# GDV normalized1-linf 14
# GDV chebyshev 0

# %%
import graco
import numpy as np
import pandas as pd
import networkx as nx
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set()

pd.set_option("display.max_columns", 50)
pd.set_option("display.max_rows", 50)

DATA_DIRECTORY = "/media/clusterduck123/joe/data/"
RAW_DATA_DIRECTORY = f"{DATA_DIRECTORY}/raw-data"
YEAST_DIRECTORY = f"{DATA_DIRECTORY}/processed-data/yeast"
NETWORK_DIRECTORY = f"{YEAST_DIRECTORY}/networks"

# %% [markdown]
# # Here we GO

# %%
DEG_FILENAME = "degannotation-e.dat"
DEG_FILEPATH = f"{RAW_DATA_DIRECTORY}/{DEG_FILENAME}"

# load DEG dat-file as dataframe and extract yeast data (DEG2001)
DEG_df = pd.read_csv(f"{DEG_FILEPATH}", delimiter='\t', encoding='latin1').loc['DEG2001'].reset_index()

# load PPI with official symbol gene names
PPI_nx = nx.read_edgelist(f"{NETWORK_DIRECTORY}/PPI_BioGRID_official.txt")

# %%
e_genes = set(DEG_df.level_1) & set(PPI_nx)
n_genes = set(PPI_nx) - e_genes

# %%
GDV = graco.orbits(PPI_nx)

# %%
e_GDV = GDV[GDV.index.isin(e_genes)]
n_GDV = GDV[GDV.index.isin(n_genes)]

# %%
fig, ax = plt.subplots(figsize=(16,8))

ax.semilogy(range(15), e_GDV.median(), 
                    label     = 'essential',
                    linewidth = 2.5,
                    alpha     = 0.75);
ax.fill_between(range(15), e_GDV.quantile(0.25), e_GDV.quantile(0.75), 
                alpha=0.1,);

ax.semilogy(range(15), n_GDV.median(), 
                    label     = 'non-essential',
                    linewidth = 2.5,
                    alpha     = 0.75);

ax.fill_between(range(15), n_GDV.quantile(0.25), n_GDV.quantile(0.75), 
                alpha=0.1,);

ax.set_title(f'Orbit analysis', fontsize=28)

ax.patch.set_alpha(0)

ax.set_xlabel(f'orbit count', fontsize=24)
ax.set_ylabel('orbit', fontsize=24)
ax.tick_params(axis='both', which='major', labelsize=24)

ax.spines['left'].set_linewidth(2.5)
ax.spines['left'].set_color('black')

ax.spines['bottom'].set_linewidth(2.5)
ax.spines['bottom'].set_color('black')

ax.legend(fontsize=14, shadow=True, facecolor=[0.95, 0.95, 0.95, 0]);

# %%
e_GDV.describe()
# Out:
# Orbit            0             1             2             3             4  \
# count  1091.000000   1091.000000  1.091000e+03   1091.000000  1.091000e+03
# mean     56.996334  14776.656279  6.683283e+03    566.835930  6.989357e+05
# std     106.390918   7217.963592  1.014364e+05   1375.778871  6.289819e+05
# min       1.000000    114.000000  0.000000e+00      0.000000  2.109300e+04
# 25%      17.000000   9806.500000  7.650000e+01     49.000000  3.069030e+05
# 50%      34.000000  13470.000000  3.660000e+02    179.000000  4.995500e+05
# 75%      63.000000  18773.500000  1.400500e+03    541.500000  9.082850e+05
# max    2580.000000  46635.000000  3.301569e+06  25341.000000  5.989000e+06
#
# Orbit             5             6             7             8              9  \
# count  1.091000e+03  1.091000e+03  1.091000e+03  1.091000e+03    1091.000000
# mean   7.631723e+05  1.218769e+07  2.961411e+06  2.702655e+04  134336.859762
# std    3.660472e+06  4.579252e+06  8.477404e+07  9.783087e+04   49706.247872
# min    0.000000e+00  3.062000e+03  0.000000e+00  0.000000e+00     386.000000
# 25%    6.487000e+04  9.527240e+06  1.475000e+02  2.655500e+03  102586.500000
# 50%    1.858670e+05  1.283578e+07  2.080000e+03  6.858000e+03  133717.000000
# 75%    5.543015e+05  1.546198e+07  1.714450e+04  2.154450e+04  172578.500000
# max    1.056862e+08  2.160916e+07  2.797888e+09  2.615691e+06  235582.000000
#
# Orbit            10            11             12            13            14
# count  1.091000e+03  1.091000e+03    1091.000000  1.091000e+03   1091.000000
# mean   4.103394e+05  1.181639e+05   24445.189734  2.044947e+04   2951.093492
# std    6.974836e+05  1.761000e+06   27620.817299  1.465516e+05   8153.654550
# min    0.000000e+00  0.000000e+00       0.000000  0.000000e+00      0.000000
# 25%    7.422150e+04  2.290000e+02    6437.000000  1.515000e+02     56.000000
# 50%    2.012580e+05  2.232000e+03   13863.000000  1.126000e+03    392.000000
# 75%    4.725115e+05  1.351900e+04   32525.000000  6.105500e+03   2072.500000
# max    8.986034e+06  5.681684e+07  184023.000000  4.147935e+06  90023.000000
